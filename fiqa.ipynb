# %%
import transformers
from datasets import load_dataset
import pandas as pd
import numpy as np
import torch
import time
from tqdm import tqdm_notebook as tqdm

# %%
from beir import util, LoggingHandler
from beir.datasets.data_loader import GenericDataLoader
import logging
import pathlib, os

#### Just some code to print debug information to stdout
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[LoggingHandler()])
#### /print debug information to stdout

# %%
import pathlib, os
from beir import util

dataset = "nfcorpus"
url = "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{}.zip".format(dataset)
out_dir = os.path.join(os.getcwd(), "datasets")
data_path = util.download_and_unzip(url, out_dir)
print("Dataset downloaded here: {}".format(data_path))
# Out:
# Dataset downloaded here: /home/toghrul/ada/ml/final/datasets/nfcorpus

# %%
# !ls datasets/scifact/
# Out:
# corpus.csv	      embeddings.csv  qrels.csv      retrieval_results.csv
# corpus.jsonl	      hybrid	      queries.csv
# cosine		      keyword_rerank  queries.jsonl
# cross_encoder_rerank  qrels	      results.csv

# %%
corpus, queries, qrels = GenericDataLoader(data_folder=data_path).load(split="test")
# Out:
# 2024-05-23 20:45:29 - Loading Corpus...
#   0%|          | 0/3633 [00:00<?, ?it/s]
# 2024-05-23 20:45:30 - Loaded 3633 TEST Documents.
# 2024-05-23 20:45:30 - Doc Example: {'text': 'Recent studies have suggested that statins, an established drug group in the prevention of cardiovascular mortality, could delay or prevent breast cancer recurrence but the effect on disease-specific mortality remains unclear. We evaluated risk of breast cancer death among statin users in a population-based cohort of breast cancer patients. The study cohort included all newly diagnosed breast cancer patients in Finland during 1995–2003 (31,236 cases), identified from the Finnish Cancer Registry. Information on statin use before and after the diagnosis was obtained from a national prescription database. We used the Cox proportional hazards regression method to estimate mortality among statin users with statin use as time-dependent variable. A total of 4,151 participants had used statins. During the median follow-up of 3.25 years after the diagnosis (range 0.08–9.0 years) 6,011 participants died, of which 3,619 (60.2%) was due to breast cancer. After adjustment for age, tumor characteristics, and treatment selection, both post-diagnostic and pre-diagnostic statin use were associated with lowered risk of breast cancer death (HR 0.46, 95% CI 0.38–0.55 and HR 0.54, 95% CI 0.44–0.67, respectively). The risk decrease by post-diagnostic statin use was likely affected by healthy adherer bias; that is, the greater likelihood of dying cancer patients to discontinue statin use as the association was not clearly dose-dependent and observed already at low-dose/short-term use. The dose- and time-dependence of the survival benefit among pre-diagnostic statin users suggests a possible causal effect that should be evaluated further in a clinical trial testing statins’ effect on survival in breast cancer patients.', 'title': 'Statin Use and Breast Cancer Survival: A Nationwide Cohort Study from Finland'}
# 2024-05-23 20:45:30 - Loading Queries...
# 2024-05-23 20:45:30 - Loaded 323 TEST Queries.
# 2024-05-23 20:45:30 - Query Example: Do Cholesterol Statin Drugs Cause Breast Cancer?

# %%
corpus_idx = list(corpus.keys())
corpus_vals = list(corpus.values())

corpus_df = pd.DataFrame(corpus_vals, index=corpus_idx)

# %%
corpus_df
# Out:
#                                                       text  \
# MED-10   Recent studies have suggested that statins, an...
# MED-14   BACKGROUND: Preclinical studies have shown tha...
# MED-118  The aims of this study were to determine the c...
# MED-301  Epilepsy or seizure disorder is one of the mos...
# MED-306  Hit Reaction Time latencies (HRT) in the Conti...
# ...                                                    ...
# MED-917  Scottish-grown red raspberries are a rich sour...
# MED-941  BACKGROUND: Common warts (verruca vulgaris) ar...
# MED-942  Apple cider vinegar products are advertised in...
# MED-952  The use of cannabis is embedded within many so...
# MED-961  BACKGROUND: Current unitage for the calciferol...
#
#                                                      title
# MED-10   Statin Use and Breast Cancer Survival: A Natio...
# MED-14   Statin use after diagnosis of breast cancer an...
# MED-118  Alkylphenols in human milk and their relations...
# MED-301  Methylmercury: A Potential Environmental Risk ...
# MED-306  Sensitivity of Continuous Performance Test (CP...
# ...                                                    ...
# MED-917  Effect of freezing and storage on the phenolic...
# MED-941  Topical vitamin A treatment of recalcitrant co...
# MED-942  Esophageal injury by apple cider vinegar table...
# MED-952                             Cannabis and the lung.
# MED-961  Vitamin D(3) is more potent than vitamin D(2) ...
#
# [3633 rows x 2 columns]

# %%
queries_df = pd.Series(queries)

# %%
from typing import List
import logging
from pydantic import BaseModel
from sentence_transformers import SentenceTransformer
# from rag import insert_document_and_embeddings, find_similar_embeddings, preprocess
from datetime import datetime
import re
from nltk import tokenize
import unicodedata
import string
import logging
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

MAX_WORD_COUNT = 256
MAX_TOKEN_COUNT = 512


model_name = "mixedbread-ai/mxbai-embed-large-v1"

tokenizer = AutoTokenizer.from_pretrained(model_name)
EMBED_MODEL = SentenceTransformer(model_name, truncate_dim=MAX_TOKEN_COUNT, device="cuda")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
EMBED_MODEL.to(device)


def encoding(text: str) -> str:
    """
    Remove unicoded data
    """
    text = unicodedata.normalize("NFKD", text)

    return text


def remove_URL(text: str) -> str:
    """
    Remove URLs
    """
    return re.sub(r"https?://\S+|www\.\S+", "", text)


def remove_non_ascii(text: str) -> str:
    """
    Remove non-ASCII characters
    """
    return re.sub(r"[^\x00-\x7f]", r"", text)


def remove_html(text: str) -> str:
    """
    Remove the html
    """
    html = re.compile(r"<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});")
    return re.sub(html, "", text)


def remove_punct(text: str) -> str:
    """
    Remove the punctuation
    """
    #     return re.sub(r'[]!"$%&\'()*+,./:;=#@?[\\^_`{|}~-]+', "", text)
    return text.translate(str.maketrans("", "", string.punctuation))


def preprocess(text: str) -> str:
    """
    Preprocess the text
    """

    text = encoding(text)
    text = remove_URL(text)
    text = remove_non_ascii(text)
    text = remove_html(text)
    # text = remove_punct(text)
    return text


def ingest_input(user_input):
    user_input = preprocess(user_input)
    # logging.info(f"Preprocessed user input")

    # Generate sentence tokens
    sentence_tokens = tokenize.sent_tokenize(user_input)
    model_input = []
    temp_input: str = ""
    if len(user_input.split(" ")) > MAX_WORD_COUNT:
        logging.info(
            f"Input contains more than {MAX_WORD_COUNT} words. Splitting the input into chunks"
        )

        # Split the input into chunks based on the sentence tokens
        for i, sent in enumerate(sentence_tokens):
            num_words_sent = len(sent.split(" "))

            # Check if the new chunk would exceed the maximum word count
            if len(temp_input.split(" ")) + num_words_sent > MAX_WORD_COUNT:

                # Append the chunk to the model input
                model_input.append(temp_input.strip())
                logging.info(
                    f"Number of words in the chunk: {len(temp_input.split(' '))}"
                )
                temp_input = sent
            else:
                temp_input += " " + sent

        # Append the last chunk to the model input
        logging.info(
            f"Number of words in the last chunk: {len(temp_input.split(' '))}"
        )
        model_input.append(temp_input)
    else:
        model_input = [user_input]

    return model_input


def read_pdf_doc(filepath):
    doc = fitz.open(filepath)
    text = ""
    for page_index, page in enumerate(doc):
        logging.info(f"page {page_index+1} out of {len(doc)}")
        tp = page.get_textpage()
        words = tp.extractWORDS()

        page_text = " ".join([word[4] for word in words])
        text += page_text + " "
    doc.close()
    return text


def generate_embeddings(text, device):
    # inputs = tokenizer(
    #     text,
    #     return_tensors="pt",
    #     truncation=True,
    #     max_length=MAX_TOKEN_COUNT,
    #     padding="max_length",
    # )
    with torch.no_grad():
        outputs = EMBED_MODEL.encode(text, device=device)

    # outputs = outputs.cpu().numpy()
    # Scale the embeddings to be between 0 and 1
    outputs = (outputs - outputs.min()) / (outputs.max() - outputs.min())
    return outputs
# Out:
# 2024-05-23 20:45:31 - Load pretrained SentenceTransformer: mixedbread-ai/mxbai-embed-large-v1

# %% [markdown]
# # Embedding Generation

# %%
text_chunks_list = []
embeddings_list = []
doc_ids = []

batch_size = 128
batch_no = 0
text_batch = []
ids_batch = []

for idx, doc in tqdm(corpus_df.iterrows(), total=len(corpus_df), desc="Processing documents"):
    text_chunks = ingest_input(doc['text'])

    start = time.time()
    text_batch.extend(text_chunks)
    ids_batch.extend([idx] * len(text_chunks))

    while len(text_batch) >= batch_size:
        sub_text_batch = text_batch[:batch_size]
        sub_ids_batch = ids_batch[:batch_size]

        embeddings = generate_embeddings(sub_text_batch, device)
        embeddings_list.append(embeddings)
        text_chunks_list.extend(sub_text_batch)
        doc_ids.extend(sub_ids_batch)

        logging.info(f">>> Generated embeddings for batch {batch_no}")
        logging.info(f"Shape of embeddings: {embeddings.shape}")
        logging.info(f"Time taken for the batch: {time.time() - start}")

        text_batch = text_batch[batch_size:]
        ids_batch = ids_batch[batch_size:]
        batch_no += 1

# Handle any remaining batches
if len(text_batch) > 0:
    torch.cuda.empty_cache()  # Clear CUDA cache before final batch
    logging.info(f"Processing remaining batch of size {len(text_batch)}")
    sub_batch_size = 128  # Same sub-batch size as the main batch
    for i in range(0, len(text_batch), sub_batch_size):
        sub_text_batch = text_batch[i:i + sub_batch_size]
        sub_ids_batch = ids_batch[i:i + sub_batch_size]

        embeddings = generate_embeddings(sub_text_batch, device)
        embeddings_list.append(embeddings)
        text_chunks_list.extend(sub_text_batch)
        doc_ids.extend(sub_ids_batch)

        logging.info(f">>> Generated embeddings for sub-batch {batch_no}-{i // sub_batch_size}")
        logging.info(f"Shape of embeddings: {embeddings.shape}")
        logging.info(f"Time taken for the sub-batch: {time.time() - start}")

        torch.cuda.empty_cache()  # Clear CUDA cache after each sub-batch

embeddings_list = np.concatenate(embeddings_list, axis=0)
doc_ids = np.array(doc_ids)
# Out:
# /tmp/ipykernel_285469/556578646.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for idx, doc in tqdm(corpus_df.iterrows(), total=len(corpus_df), desc="Processing documents"):
# Processing documents:   0%|          | 0/3633 [00:00<?, ?it/s]
# 2024-05-23 18:33:32 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:33:32 - Number of words in the chunk: 233
# 2024-05-23 18:33:32 - Number of words in the last chunk: 30
# 2024-05-23 18:33:32 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:33:32 - Number of words in the chunk: 245
# 2024-05-23 18:33:32 - Number of words in the last chunk: 38
# 2024-05-23 18:33:32 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:33:32 - Number of words in the chunk:
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:36:04 - >>> Generated embeddings for batch 34
# 2024-05-23 18:36:04 - Shape of embeddings: (128, 512)
# 2024-05-23 18:36:04 - Time taken for the batch: 4.36688756942749
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 234
# 2024-05-23 18:36:04 - Number of words in the chunk: 241
# 2024-05-23 18:36:04 - Number of words in the last chunk: 61
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 244
# 2024-05-23 18:36:04 - Number of words in the last chunk: 64
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 255
# 2024-05-23 18:36:04 - Number of words in the last chunk: 140
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 230
# 2024-05-23 18:36:04 - Number of words in the last chunk: 102
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 234
# 2024-05-23 18:36:04 - Number of words in the last chunk: 26
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 247
# 2024-05-23 18:36:04 - Number of words in the last chunk: 22
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 248
# 2024-05-23 18:36:04 - Number of words in the last chunk: 32
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 239
# 2024-05-23 18:36:04 - Number of words in the last chunk: 81
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 247
# 2024-05-23 18:36:04 - Number of words in the last chunk: 24
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 225
# 2024-05-23 18:36:04 - Number of words in the last chunk: 82
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 236
# 2024-05-23 18:36:04 - Number of words in the last chunk: 143
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 213
# 2024-05-23 18:36:04 - Number of words in the last chunk: 109
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 238
# 2024-05-23 18:36:04 - Number of words in the last chunk: 26
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 251
# 2024-05-23 18:36:04 - Number of words in the last chunk: 8
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 249
# 2024-05-23 18:36:04 - Number of words in the last chunk: 30
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 250
# 2024-05-23 18:36:04 - Number of words in the last chunk: 58
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 255
# 2024-05-23 18:36:04 - Number of words in the last chunk: 8
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 241
# 2024-05-23 18:36:04 - Number of words in the last chunk: 45
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 236
# 2024-05-23 18:36:04 - Number of words in the last chunk: 112
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 243
# 2024-05-23 18:36:04 - Number of words in the last chunk: 29
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 255
# 2024-05-23 18:36:04 - Number of words in the last chunk: 32
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 241
# 2024-05-23 18:36:04 - Number of words in the last chunk: 26
# 2024-05-23 18:36:04 - Input contains more than 256 words. Splitting the input into chunks
# 2024-05-23 18:36:04 - Number of words in the chunk: 243
# 2024-05-23 18:36:04 - Number of words in the last chunk: 19
# 2024-05-23 18:36:04 - Processing remaining batch of size 117
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:36:08 - >>> Generated embeddings for sub-batch 35-0
# 2024-05-23 18:36:08 - Shape of embeddings: (117, 512)
# 2024-05-23 18:36:08 - Time taken for the sub-batch: 3.7609269618988037

# %%
torch.cuda.empty_cache()

# %%
# Convert the embeddings and doc_ids to a DataFrame
embeddings_df = pd.DataFrame({
    'text': text_chunks_list,
    'embedding': embeddings_list.tolist(),
    'doc_id': doc_ids
})

# %%
embeddings_df.to_csv(os.path.join(data_path, "embeddings.csv"), index=False)

# %% [markdown]
# # Retrieval

# %%
embeddings_df = pd.read_csv(os.path.join(data_path, "embeddings.csv"))

# %%
embeddings_df['embedding'][0]
# Out:
# '[0.4984809  0.5466461  0.49245688 0.57978016 0.52682066 0.4503061\n 0.5709185  0.60514444 0.55339444 0.71970266 0.6294538  0.33047262\n 0.5528569  0.47545147 0.5932326  0.6088847  0.49650493 0.37622535\n 0.4121623  0.6784761  0.48273173 0.6050354  0.3916255  0.56188047\n 0.40015402 0.5913703  0.600369   0.4440864  0.74994075 0.7629428\n 0.4217622  0.44717902 0.6703402  0.26622513 0.49527502 0.48728397\n 0.56444687 0.34291488 0.43436
_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4597 entries, 0 to 4596
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   text                4597 non-null   object
#  1   embedding           4597 non-null   object
#  2   doc_id              4597 non-null   object
#  3   sentence_embedding  4597 non-null   object
# dtypes: object(4)
# memory usage: 143.8+ KB

# %%
from sentence_transformers import SentenceTransformer, util


def sentence_similarity(text1, text2):
    embedding_1 = model.encode(text1, convert_to_tensor=True)
    embedding_2 = model.encode(text2, convert_to_tensor=True)
    o = util.pytorch_cos_sim(embedding_1, embedding_2)
    return o.item()


model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
# Out:
# 2024-05-23 20:45:50 - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2024-05-23 20:45:52 - Use pytorch device_name: cuda

# %% [markdown]
# ## Sentence Embedding Generation

# %%
text_batch = []
sentence_embeddings_list = []
batch_size = 128
batch_no = 0

for idx, row in tqdm(embeddings_df.iterrows(), total=len(embeddings_df), desc="Processing queries"):
    text_batch.append(row['text'])

    while len(text_batch) >= batch_size:
        sub_text_batch = text_batch[:batch_size]

        start = time.time()
        embeddings = model.encode(sub_text_batch)
        sentence_embeddings_list.extend(embeddings.tolist())

        logging.info(f">>> Generated embeddings for batch {batch_no}")
        logging.info(f"Shape of embeddings: {embeddings.shape}")
        logging.info(f"Time taken for the batch: {time.time() - start}")

        text_batch = text_batch[batch_size:]
        batch_no += 1

# Handle any remaining batches
if len(text_batch) > 0:
    torch.cuda.empty_cache()  # Clear CUDA cache before final batch
    logging.info(f"Processing remaining batch of size {len(text_batch)}")
    sub_batch_size = 128  # Same sub-batch size as the main batch
    for i in range(0, len(text_batch), sub_batch_size):
        sub_text_batch = text_batch[i:i + sub_batch_size]
        start = time.time()
        embeddings = model.encode(sub_text_batch)
        sentence_embeddings_list.extend(embeddings.tolist())

        logging.info(f">>> Generated embeddings for sub-batch {batch_no}-{i // sub_batch_size}")
        logging.info(f"Shape of embeddings: {embeddings.shape}")
        logging.info(f"Time taken for the sub-batch: {time.time() - start}")

        torch.cuda.empty_cache()  # Clear CUDA cache after each sub-batch

embeddings_df["sentence_embedding"] = sentence_embeddings_list
# Out:
# /tmp/ipykernel_293519/3108265375.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for idx, row in tqdm(embeddings_df.iterrows(), total=len(embeddings_df), desc="Processing queries"):
# Processing queries:   0%|          | 0/4597 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:50 - >>> Generated embeddings for batch 0
# 2024-05-23 18:46:50 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:50 - Time taken for the batch: 0.7847602367401123
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:50 - >>> Generated embeddings for batch 1
# 2024-05-23 18:46:50 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:50 - Time taken for the batch: 0.2757422924041748
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:50 - >>> Generated embeddings for batch 2
# 2024-05-23 18:46:50 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:50 - Time taken for the batch: 0.2449643611907959
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:51 - >>> Generated embeddings for batch 3
# 2024-05-23 18:46:51 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:51 - Time taken for the batch: 0.21411466598510742
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:51 - >>> Generated embeddings for batch 4
# 2024-05-23 18:46:51 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:51 - Time taken for the batch: 0.2305915355682373
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:51 - >>> Generated embeddings for batch 5
# 2024-05-23 18:46:51 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:51 - Time taken for the batch: 0.21850204467773438
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:51 - >>> Generated embeddings for batch 6
# 2024-05-23 18:46:51 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:51 - Time taken for the batch: 0.2244856357574463
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:52 - >>> Generated embeddings for batch 7
# 2024-05-23 18:46:52 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:58 - >>> Generated embeddings for batch 33
# 2024-05-23 18:46:58 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:58 - Time taken for the batch: 0.22333121299743652
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:58 - >>> Generated embeddings for batch 34
# 2024-05-23 18:46:58 - Shape of embeddings: (128, 384)
# 2024-05-23 18:46:58 - Time taken for the batch: 0.23633527755737305
# 2024-05-23 18:46:58 - Processing remaining batch of size 117
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-05-23 18:46:58 - >>> Generated embeddings for sub-batch 35-0
# 2024-05-23 18:46:58 - Shape of embeddings: (117, 384)
# 2024-05-23 18:46:58 - Time taken for the sub-batch: 0.40082240104675293

# %%
embeddings_df.dropna(inplace=True)
embeddings_df.info()

embeddings_df.to_csv(os.path.join(data_path, "embeddings.csv"), index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4597 entries, 0 to 4596
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   text                4597 non-null   object
#  1   embedding           4597 non-null   object
#  2   doc_id              4597 non-null   object
#  3   sentence_embedding  4597 non-null   object
# dtypes: object(4)
# memory usage: 143.8+ KB

# %% [markdown]
# ## Query Embedding Generation

# %%
queries_df = pd.DataFrame({
    'query_id': list(queries.keys()),
    'query': list(queries.values())
})
queries_df
# Out:
#        query_id                                              query
# 0       PLAIN-2   Do Cholesterol Statin Drugs Cause Breast Cancer?
# 1      PLAIN-12                Exploiting Autophagy to Live Longer
# 2      PLAIN-23  How to Reduce Exposure to Alkylphenols Through...
# 3      PLAIN-33          What’s Driving America’s Obesity Problem?
# 4      PLAIN-44              Who Should be Careful About Curcumin?
# ..          ...                                                ...
# 318  PLAIN-3432                       Healthy Chocolate Milkshakes
# 319  PLAIN-3442                          The Healthiest Vegetables
# 320  PLAIN-3452                           Bowel Movement Frequency
# 321  PLAIN-3462                      Olive Oil and Artery Function
# 322  PLAIN-3472  How Doctors Responded to Being Named a Leading...
#
# [323 rows x 2 columns]

# %%
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
import torch
import logging
from tqdm import tqdm

retrieved_docs_list = []
retrieved_text_list = []
query_ids = []
batch_size = 128
k = 10
query_batch = []
query_embeddings_list = []
query_ids = []
batch_no = 0

for idx, query in tqdm(queries_df.iterrows(), total=len(queries_df), desc="Processing queries"):
    query_batch.append(ingest_input(query['query'])[0])

    while len(query_batch) >= batch_size:
        sub_query_batch = query_batch[:batch_size]

        start = time.time()
        query_embeddings = generate_embeddings(sub_query_batch, device)
        query_embeddings_list.extend(query_embeddings.tolist())
        # query_ids.extend([query['query_id']] * batch_size)

        logging.info(f">>> Generated embeddings for batch {batch_no}")
        logging.info(f"Shape of embeddings: {query_embeddings.shape}")
        logging.info(f"Time taken for the batch: {time.time() - start}")

        query_batch = query_batch[batch_size:]
        batch_no += 1

# Handle any remaining queries
if len(query_batch) > 0:
    torch.cuda.empty_cache()  # Clear CUDA cache before final batch
    logging.info(f"Processing remaining batch of size {len(query_batch)}")
    sub_batch_size = 128  # Same sub-batch size as the main batch
    for i in range(0, len(query_batch), sub_batch_size):
        sub_query_batch = query_batch[i:i + sub_batch_size]
        start = time.time()

        query_embeddings = generate_embeddings(sub_query_batch, device)
        query_embeddings_list.extend(query_embeddings.tolist())
        # query_ids.extend([query['query_id']] * len(sub_query_batch))

        logging.info(f">>> Generated embeddings for sub-batch {batch_no}-{i // sub_batch_size}")
        logging.info(f"Shape of embeddings: {query_embeddings.shape}")
        logging.info(f"Time taken for the sub-batch: {time.time() - start}")

        torch.cuda.empty_cache()  # Clear CUDA cache after each sub-batch

# The final embeddings list can now be used as required
# Example usage:
# queries_df["query_embedding"] = query_embeddings_list
# Out:
# Processing queries:   0%|          | 0/323 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing queries:  40%|███▉      | 128/323 [00:00<00:00, 250.03it/s]
# 2024-05-23 18:47:06 - >>> Generated embeddings for batch 0
# 2024-05-23 18:47:06 - Shape of embeddings: (128, 512)
# 2024-05-23 18:47:06 - Time taken for the batch: 0.4994323253631592
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing queries: 100%|██████████| 323/323 [00:00<00:00, 479.12it/s]
# 2024-05-23 18:47:06 - >>> Generated embeddings for batch 1
# 2024-05-23 18:47:06 - Shape of embeddings: (128, 512)
# 2024-05-23 18:47:06 - Time taken for the batch: 0.1470808982849121
# 2024-05-23 18:47:06 - Processing remaining batch of size 67
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# 2024-05-23 18:47:06 - >>> Generated embeddings for sub-batch 2-0
# 2024-05-23 18:47:06 - Shape of embeddings: (67, 512)
# 2024-05-23 18:47:06 - Time taken for the sub-batch: 0.2095174789428711

# %%
queries_df = pd.DataFrame({
    'query_id': queries_df['query_id'],
    'query': queries_df['query'],
    'query_embedding': query_embeddings_list
})
queries_df.shape
# Out:
# (323, 3)

# %%
queries_df.to_csv(os.path.join(data_path, "queries.csv"), index=False)
queries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   query_id         323 non-null    object
#  1   query            323 non-null    object
#  2   query_embedding  323 non-null    object
# dtypes: object(3)
# memory usage: 7.7+ KB

# %%
embeddings_df.dropna(inplace=True)
embeddings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4597 entries, 0 to 4596
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   text                4597 non-null   object
#  1   embedding           4597 non-null   object
#  2   doc_id              4597 non-null   object
#  3   sentence_embedding  4597 non-null   object
# dtypes: object(4)
# memory usage: 143.8+ KB

# %% [markdown]
# ## Document Keyword Corpus Generation

# %%
queries_df = pd.read_csv(os.path.join(data_path, "queries.csv"))
queries_df
# Out:
#        query_id                                              query  \
# 0       PLAIN-2   Do Cholesterol Statin Drugs Cause Breast Cancer?
# 1      PLAIN-12                Exploiting Autophagy to Live Longer
# 2      PLAIN-23  How to Reduce Exposure to Alkylphenols Through...
# 3      PLAIN-33          What’s Driving America’s Obesity Problem?
# 4      PLAIN-44              Who Should be Careful About Curcumin?
# ..          ...                                                ...
# 318  PLAIN-3432                       Healthy Chocolate Milkshakes
# 319  PLAIN-3442                          The Healthiest Vegetables
# 320  PLAIN-3452                           Bowel Movement Frequency
# 321  PLAIN-3462                      Olive Oil and Artery Function
# 322  PLAIN-3472  How Doctors Responded to Being Named a Leading...
#
#                                        query_embedding
# 0    [0.3830738365650177, 0.5533143877983093, 0.667...
# 1    [0.6694016456604004, 0.4906133711338043, 0.433...
# 2    [0.288175493478775, 0.6211127638816833, 0.5944...
# 3    [0.44784390926361084, 0.6733686327934265, 0.45...
# 4    [0.22403667867183685, 0.4641282260417938, 0.48...
# ..                                                 ...
# 318  [0.45116451382637024, 0.604766845703125, 0.598...
# 319  [0.3944050073623657, 0.5450353622436523, 0.499...
# 320  [0.565150797367096, 0.6456841230392456, 0.4579...
# 321  [0.5049484372138977, 0.6557204127311707, 0.536...
# 322  [0.6267022490501404, 0.5020505785942078, 0.420...
#
# [323 rows x 3 columns]

# %%
from rank_bm25 import BM25Okapi

TEXT_CORPUS = embeddings_df['text'].values.tolist()
TOKENIZED_CORPUS = [tokenize.word_tokenize(doc) for doc in TEXT_CORPUS]
BM25_TC = BM25Okapi(TOKENIZED_CORPUS)

# %%
embeddings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4597 entries, 0 to 4596
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   text                4597 non-null   object
#  1   embedding           4597 non-null   object
#  2   doc_id              4597 non-null   object
#  3   sentence_embedding  4597 non-null   object
# dtypes: object(4)
# memory usage: 143.8+ KB

# %%
embeddings_df["sentence_embedding"] = embeddings_df["sentence_embedding"].apply(lambda x: np.array(x).astype(np.float32))
embeddings_df["embedding"] = embeddings_df["embedding"].apply(lambda x: np.array(x).astype(np.float32))

# %%
from sentence_transformers.util import cos_sim
import torch
# Convert embeddings to NumPy arrays of floats and stack them
DOC_EMBEDDINGS = torch.tensor(
    np.vstack(embeddings_df["embedding"]).astype(np.float32)
).to(device)

def find_similar_embeddings(
    df: pd.DataFrame,
    query: str, 
    query_embedding: List[float], 
    top_k: int = 10, 
    alpha: float = 0.7,
    similarity_threshold: float = 0.5,
    method: str = "cosine"
):
    query_embedding = torch.tensor(np.array(query_embedding).reshape(1, -1).astype(np.float32)).to(device)

    # Calculate cosine similarities using GPU
    similarities = cos_sim(query_embedding, DOC_EMBEDDINGS).flatten().cpu().numpy()

    if method == "hybrid":
        query_tokens = tokenize.word_tokenize(query)
        doc_scores = BM25_TC.get_scores(query_tokens)
        similarities = alpha * similarities + (1 - alpha) * doc_scores

    # Add similarities to DataFrame
    df["similarity"] = similarities

    # Filter based on similarity threshold and sort
    filtered_df = df[df["similarity"] > similarity_threshold]
    if filtered_df.empty:
        return [], [], []
    
    results_df = filtered_df.nlargest(top_k, "similarity")

    if method == "keyword_rerank":
        tokenized_corpus = [tokenize.word_tokenize(doc) for doc in results_df["text"].tolist()]
        bm25 = BM25Okapi(tokenized_corpus)
        query_tokens = tokenize.word_tokenize(query)
        
        doc_scores = bm25.get_scores(query_tokens)
        doc_scores_idx = np.argsort(doc_scores)[::-1]
        
        results_df = results_df.iloc[doc_scores_idx].reset_index(drop=True)
        
    elif method == "cross_encoder_rerank":
        doc_sentence_embeddings = torch.tensor(np.vstack(results_df["sentence_embedding"].apply(np.array).values)).to(device)
        
        with torch.no_grad():
            query_sentence_embedding = model.encode(query, device=device).reshape(1, -1)
        # Move embeddings to GPU
        query_sentence_embedding = torch.tensor(query_sentence_embedding).to(device)
        doc_sentence_embeddings = doc_sentence_embeddings.to(device)
        
        cross_encoder_scores = cos_sim(query_sentence_embedding, doc_sentence_embeddings).flatten().cpu().numpy()
        doc_scores_idx = np.argsort(cross_encoder_scores)[::-1]
        
        results_df = results_df.iloc[doc_scores_idx].reset_index(drop=True)

    return (
        results_df["doc_id"].values.tolist(),
        results_df["similarity"].values.tolist(),
        results_df["text"].values.tolist(),
    )

# %% [markdown]
# ## Retrieval of Relevant Documents

# %%
k = 50

# methods_list = ["hybrid", "cosine"]
methods_list = ["hybrid", "cosine", "cross_encoder_rerank", "keyword_rerank"]


for method in methods_list:
    logging.info(f">>> Retrieving documents using {method} similarity <<<")
    retrieved_docs_list = []
    retrieved_text_list = []
    retrieved_sim_list = []
    query_ids = []
    for idx, row in tqdm(
        queries_df.iterrows(), total=len(queries_df), desc="Finding similar embeddings"
    ):
        doc_ids, sim_scores, similar_texts = find_similar_embeddings(
            embeddings_df,
            row["query"],
            row["query_embedding"],
            top_k=k,
            alpha=0.5,
            similarity_threshold=0.5,
            method=method,
        )
        retrieved_docs_list.append(doc_ids)
        retrieved_sim_list.append(sim_scores)
        retrieved_text_list.append(similar_texts)

    retrieval_df = pd.DataFrame(
        {
            "query_id": queries_df["query_id"],
            "query": queries_df["query"],
            f"retrieved_docs_top{k}": retrieved_docs_list,
            f"retrieved_texts_top{k}": retrieved_text_list,
            f"retrieved_sim_top{k}": retrieved_sim_list,
        }
    )

    save_path = os.path.join(data_path, method)
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    retrieval_df.to_csv(os.path.join(save_path, "retrieval_results.csv"), index=False)
# Out:
# 2024-05-23 18:51:46 - >>> Retrieving documents using hybrid similarity <<<
# Finding similar embeddings: 100%|██████████| 323/323 [00:02<00:00, 139.56it/s]
# 2024-05-23 18:51:49 - >>> Retrieving documents using cosine similarity <<<
# Finding similar embeddings: 100%|██████████| 323/323 [00:01<00:00, 260.58it/s]
# 2024-05-23 18:51:50 - >>> Retrieving documents using cross_encoder_rerank similarity <<<
# Finding similar embeddings:   0%|          | 0/323 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:   1%|          | 3/323 [00:00<00:11, 27.31it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:   2%|▏         | 7/323 [00:00<00:10, 31.28it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:   4%|▎         | 12/323 [00:00<00:08, 36.22it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:   6%|▌         | 18/323 [00:00<00:07, 42.67it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:   7%|▋         | 24/323 [00:00<00:06, 45.93it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:   9%|▉         | 30/323 [00:00<00:06, 48.09it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  11%|█         | 35/323 [00:00<00:06, 46.14it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  12%|█▏        | 40/323 [00:00<00:06, 43.72it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  14%|█▍        | 46/323 [00:01<00:06, 45.88it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  16%|█▌        | 51/323 [00:01<00:06, 44.16it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  18%|█▊        | 57/323 [00:01<00:05, 46.02it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  19%|█▉        | 62/323 [00:01<00:05, 45.51it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  21%|██        | 67/323 [00:01<00:05, 46.69it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  22%|██▏       | 72/323 [00:01<00:05, 46.52it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  24%|██▍       | 78/323 [00:01<00:05, 48.19it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  26%|██▌       | 84/323 [00:01<00:04, 49.33it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  28%|██▊       | 89/323 [00:01<00:04, 48.44it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  29%|██▉       | 94/323 [00:02<00:04, 48.61it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  31%|███       | 99/323 [00:02<00:04, 47.82it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  32%|███▏      | 104/323 [00:02<00:04, 47.68it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  34%|███▎      | 109/323 [00:02<00:04, 45.57it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  35%|███▌      | 114/323 [00:02<00:05, 40.33it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  37%|███▋      | 119/323 [00:02<00:05, 40.02it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  38%|███▊      | 124/323 [00:02<00:05, 39.25it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  40%|███▉      | 129/323 [00:02<00:04, 41.15it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  41%|████▏     | 134/323 [00:03<00:04, 42.18it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  43%|████▎     | 140/323 [00:03<00:04, 44.88it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  45%|████▍     | 145/323 [00:03<00:03, 45.54it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  47%|████▋     | 151/323 [00:03<00:03, 48.18it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  48%|████▊     | 156/323 [00:03<00:03, 48.62it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  50%|████▉     | 161/323 [00:03<00:03, 48.22it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  52%|█████▏    | 167/323 [00:03<00:03, 50.48it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  54%|█████▎    | 173/323 [00:03<00:03, 49.41it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  55%|█████▌    | 178/323 [00:03<00:02, 49.01it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  57%|█████▋    | 183/323 [00:04<00:02, 48.17it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  58%|█████▊    | 188/323 [00:04<00:02, 46.32it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  60%|██████    | 194/323 [00:04<00:02, 47.46it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  62%|██████▏   | 200/323 [00:04<00:02, 50.25it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  64%|██████▍   | 206/323 [00:04<00:02, 50.53it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  66%|██████▌   | 212/323 [00:04<00:02, 51.28it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  67%|██████▋   | 218/323 [00:04<00:02, 50.63it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  69%|██████▉   | 224/323 [00:04<00:02, 48.82it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  71%|███████   | 229/323 [00:04<00:02, 46.55it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  72%|███████▏  | 234/323 [00:05<00:01, 46.15it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  74%|███████▍  | 239/323 [00:05<00:01, 43.66it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  76%|███████▌  | 244/323 [00:05<00:01, 44.36it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  77%|███████▋  | 250/323 [00:05<00:01, 46.99it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  79%|███████▉  | 255/323 [00:05<00:01, 46.32it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  80%|████████  | 260/323 [00:05<00:01, 43.13it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  82%|████████▏ | 265/323 [00:05<00:01, 44.83it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  84%|████████▎ | 270/323 [00:05<00:01, 44.66it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  85%|████████▌ | 275/323 [00:06<00:01, 41.30it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  87%|████████▋ | 280/323 [00:06<00:01, 38.80it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  88%|████████▊ | 284/323 [00:06<00:01, 36.26it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  89%|████████▉ | 289/323 [00:06<00:00, 38.67it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  91%|█████████▏| 295/323 [00:06<00:00, 42.42it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  93%|█████████▎| 301/323 [00:06<00:00, 45.51it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  95%|█████████▌| 307/323 [00:06<00:00, 47.54it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  97%|█████████▋| 312/323 [00:06<00:00, 46.72it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings:  98%|█████████▊| 318/323 [00:06<00:00, 48.42it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding similar embeddings: 100%|██████████| 323/323 [00:07<00:00, 45.35it/s]
# 2024-05-23 18:51:58 - >>> Retrieving documents using keyword_rerank similarity <<<
# Finding similar embeddings: 100%|██████████| 323/323 [00:14<00:00, 22.74it/s]

# %% [markdown]
# # Evaluation

# %%
list(qrels.values())
# Out:
# [{'MED-2427': 2,
#   'MED-10': 2,
#   'MED-2429': 2,
#   'MED-2430': 2,
#   'MED-2431': 2,
#   'MED-14': 2,
#   'MED-2432': 2,
#   'MED-2428': 1,
#   'MED-2440': 1,
#   'MED-2434': 1,
#   'MED-2435': 1,
#   'MED-2436': 1,
#   'MED-2437': 1,
#   'MED-2438': 1,
#   'MED-2439': 1,
#   'MED-3597': 1,
#   'MED-3598': 1,
#   'MED-3599': 1,
#   'MED-4556': 1,
#   'MED-4559': 1,
#   'MED-4560': 1,
#   'MED-4828': 1,
#   'MED-4829': 1,
#   'MED-4830': 1},
#  {'MED-2513': 2,
#   'MED-5237': 2,
#   'MED-2517': 2,
#   'MED-2518': 2,
#   'MED-2519': 2,
#   'MED-2520': 2,
#   'MED-2521': 2,
#   'MED-2514': 1,
#   'MED-2943': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED
 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-2896': 2,
#   'MED-2899': 2,
#   'MED-2900': 2,
#   'MED-2901': 2,
#   'MED-2882': 1,
#   'MED-2898': 1,
#   'MED-2884': 1,
#   'MED-2885': 1,
#   'MED-2886': 1,
#   'MED-2888': 1,
#   'MED-2889': 1,
#   'MED-2890': 1,
#   'MED-2891': 1,
#   'MED-2892': 1,
#   'MED-2893': 1,
#   'MED-2894': 1,
#   'MED-2895': 1,
#   'MED-4384': 1,
#   'MED-4523': 1,
#   'MED-2966': 1,
#   'MED-2967': 1,
#   'MED-2968': 1,
#   'MED-2969': 1,
#   'MED-2970': 1,
#   'MED-2971': 1,
#   'MED-2972': 1,
#   'MED-4095': 1,
#   'MED-4383': 1,
#   'MED-4385': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-2991': 2,
#   'MED-3085': 1,
#   'MED-3086': 1,
#   'MED-3087': 1,
#   'MED-3088': 1,
#   'MED-3089': 1,
#   'MED-3090': 1,
#   'MED-3091': 1,
#   'MED-3092': 1,
#   'MED-3093': 1,
#   'MED-3094': 1,
#   'MED-3095': 1,
#   'MED-3096': 1,
#   'MED-3880': 1,
#   'MED-4132': 1,
#   'MED-3882': 1,
#   'MED-4136': 1,
#   'MED-3884': 1,
#   'MED-3885': 1,
#   'MED-3886': 1,
#   'MED-3887': 1,
#   'MED-3888': 1,
#   'MED-3889': 1,
#   'MED-3890': 1,
#   'MED-3891': 1,
#   'MED-3892': 1,
#   'MED-4068': 1,
#   'MED-4069': 1,
#   'MED-4070': 1,
#   'MED-4071': 1,
#   'MED-4072': 1,
#   'MED-4073': 1,
#   'MED-5197': 1,
#   'MED-4075': 1,
#   'MED-4128': 1,
#   'MED-4129': 1,
#   'MED-4130': 1,
#   'MED-4131': 1,
#   'MED-4133': 1,
#   'MED-4134': 1,
#   'MED-4135': 1,
#   'MED-4137': 1,
#   'MED-4138': 1,
#   'MED-4139': 1,
#   'MED-4140': 1,
#   'MED-4141': 1,
#   'MED-4142': 1,
#   'MED-4143': 1,
#   'MED-4746': 1,
#   'MED-4804': 1,
#   'MED-4976': 1,
#   'MED-4972': 1,
#   'MED-5110': 1,
#   'MED-5169': 1,
#   'MED-5170': 1},
#  {'MED-332': 2,
#   'MED-3090': 2,
#   'MED-334': 2,
#   'MED-335': 2,
#   'MED-3092': 2,
#   'MED-3094': 2,
#   'MED-3085': 1,
#   'MED-3086': 1,
#   'MED-3087': 1,
#   'MED-3088': 1,
#   'MED-3091': 1,
#   'MED-3095': 1,
#   'MED-3089': 1,
#   'MED-3093': 1,
#   'MED-3096': 1,
#   'MED-3378': 1,
#   'MED-3379': 1,
#   'MED-3380': 1,
#   'MED-3381': 1,
#   'MED-3382': 1,
#   'MED-3960': 1,
#   'MED-3961': 1,
#   'MED-3962': 1,
#   'MED-3963': 1,
#   'MED-3964': 1,
#   'MED-3965': 1,
#   'MED-3966': 1,
#   'MED-3967': 1,
#   'MED-3968': 1,
#   'MED-3969': 1,
#   'MED-3970': 1,
#   'MED-4316': 1,
#   'MED-4317': 1,
#   'MED-4318': 1,
#   'MED-5340': 1,
#   'MED-4327': 1,
#   'MED-4553': 1,
#   'MED-4554': 1,
#   'MED-4912': 1,
#   'MED-4911': 1,
#   'MED-4936': 1,
#   'MED-4932': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-
 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-3549': 2,
#   'MED-3550': 2,
#   'MED-3551': 2,
#   'MED-3554': 2,
#   'MED-3555': 2,
#   'MED-3548': 1,
#   'MED-3552': 1,
#   'MED-3553': 1,
#   'MED-4089': 1,
#   'MED-4090': 1,
#   'MED-4652': 1,
#   'MED-5072': 1,
#   'MED-5069': 1,
#   'MED-5070': 1,
#   'MED-5071': 1,
#   'MED-5341': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5342': 1},
#  {'MED-3618': 2,
#   'MED-3621': 2,
#   'MED-3619': 1,
#   'MED-3601': 1,
#   'MED-3602': 1,
#   'MED-3603': 1,
#   'MED-3604': 1,
#   'MED-3615': 1,
#   'MED-3606': 1,
#   'MED-3607': 1,
#   'MED-3608': 1,
#   'MED-3609': 1,
#   'MED-3610': 1,
#   'MED-3617': 1,
#   'MED-3620': 1,
#   'MED-3622': 1,
#   'MED-3623': 1,
#   'MED-3624': 1,
#   'MED-3625': 1,
#   'MED-3626': 1,
#   'MED-3627': 1,
#   'MED-3628': 1,
#   'MED-3629': 1,
#   'MED-3630': 1,
#   'MED-3631': 1,
#   'MED-3632': 1,
#   'MED-3633': 1,
#   'MED-3634': 1,
#   'MED-3635': 1,
#   'MED-3636': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-3679': 2,
#   'MED-3671': 1,
#   'MED-3672': 1,
#   'MED-3673': 1,
#   'MED-3674': 1,
#   'MED-3675': 1,
#   'MED-3676': 1,
#   'MED-3677': 1,
#   'MED-3678': 1,
#   'MED-3680': 1,
#   'MED-3681': 1,
#   'MED-3682': 1,
#   'MED-3683': 1,
#   'MED-3693': 1,
#   'MED-3685': 1,
#   'MED-3686': 1,
#   'MED-3687': 1,
#   'MED-3688': 1,
#   'MED-3689': 1,
#   'MED-3690': 1,
#   'MED-3691': 1,
#   'MED-3692': 1,
#   'MED-3694': 1,
#   'MED-3695': 1,
#   'MED-4566': 1,
#   'MED-4574': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-3762': 2,
#   'MED-3763': 2,
#   'MED-3764': 2,
#   'MED-3696': 1,
#   'MED-3697': 1,
#   'MED-3698': 1,
#   'MED-3699': 1,
#   'MED-3700': 1,
#   'MED-3701': 1,
#   'MED-3765': 1,
#   'MED-3766': 1,
#   'MED-3767': 1,
#   'MED-3768': 1,
#   'MED-4507': 1,
#   'MED-4994': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-3815': 2,
#   'MED-3816': 2,
#   'MED-3820': 2,
#   'MED-3821': 2,
#   'MED-3817': 2,
#   'MED-3818': 1,
#   'MED-3819': 1,
#   'MED-3822': 1,
#   'MED-4256': 1,
#   'MED-4257': 1,
#   'MED-4546': 1,
#   'MED-4547': 1,
#   'MED-4958': 1,
#   'MED-4959': 1,
#   'MED-4960': 1,
#   'MED-4961': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-3904': 1,
#   'MED-5175': 1,
#   'MED-4810': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-3960': 1,
#   'MED-3961': 1,
#   'MED-3962': 1,
#   'MED-3963': 1,
#   'MED-3964': 1,
#   'MED-3965': 1,
#   'MED-3966': 1,
#   'MED-3967': 1,
#   'MED-3968': 1,
#   'MED-3969': 1,
#   'MED-3970': 1,
#   'MED-4068': 1,
#   'MED-4069': 1,
#   'MED-4070': 1,
#   'MED-4071': 1,
#   'MED-4072': 1,
#   'MED-4073': 1,
#   'MED-5197': 1,
#   'MED-4075': 1,
#   'MED-4853': 1,
#   'MED-4128': 1,
#   'MED-4129': 1,
#   'MED-4130': 1,
#   'MED-4131': 1,
#   'MED-4132': 1,
#   'MED-4133': 1,
#   'MED-4134': 1,
#   'MED-4135': 1,
#   'MED-4136': 1,
#   'MED-4137': 1,
#   'MED-4138': 1,
#   'MED-4139': 1,
#   'MED-4140': 1,
#   'MED-4141': 1,
#   'MED-4142': 1,
#   'MED-4143': 1,
#   'MED-4167': 1,
#   'MED-4168': 1,
#   'MED-4333': 1,
#   'MED-4337': 1,
#   'MED-4342': 1,
#   'MED-4349': 1,
#   'MED-5326': 1,
#   'MED-4488': 1,
#   'MED-4489': 1,
#   'MED-4490': 1,
#   'MED-4491': 1,
#   'MED-4492': 1,
#   'MED-4627': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-4053': 1,
#   'MED-4058': 1,
#   'MED-4055': 1,
#   'MED-4060': 1,
#   'MED-4057': 1,
#   'MED-4059': 1,
#   'MED-4075': 1,
#   'MED-4068': 1,
#   'MED-4069': 1,
#   'MED-4070': 1,
#   'MED-4072': 1,
#   'MED-5197': 1,
#   'MED-4071': 1,
#   'MED-4073': 1,
#   'MED-4180': 1,
#   'MED-4365': 1,
#   'MED-4474': 1,
#   'MED-4475': 1,
#   'MED-4476': 1,
#   'MED-4477': 1,
#   'MED-4488': 1,
#   'MED-4489': 1,
#   'MED-4490': 1,
#   'MED-4491': 1,
#   'MED-4492': 1,
#   'MED-4726': 1,
#   'MED-4976': 1,
#   'MED-4972': 1,
#   'MED-4973': 1,
#   'MED-4974': 1,
#   'MED-4975': 1,
#   'MED-4978': 1,
#   'MED-5104': 1,
#   'MED-5105': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-4103': 1,
#   'MED-4104': 1,
#   'MED-4853': 1,
#   'MED-4843': 1,
#   'MED-4844': 1,
#   'MED-4845': 1,
#   'MED-4846': 1,
#   'MED-4847': 1,
#   'MED-4848': 1,
#   'MED-4849': 1,
#   'MED-4850': 1,
#   'MED-4851': 1,
#   'MED-4852': 1,
#   'MED-4854': 1,
#   'MED-5090': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-4544': 1,
#   'MED-4150': 1,
#   'MED-5341': 1,
#   'MED-5337': 1,
#   'MED-4464': 1,
#   'MED-4465': 1,
#   'MED-4468': 1,
#   'MED-4469': 1,
#   'MED-4501': 1,
#   'MED-4502': 1,
#   'MED-4543': 1,
#   'MED-4538': 1,
#   'MED-4539': 1,
#   'MED-4540': 1,
#   'MED-4541': 1,
#   'MED-4671': 1,
#   'MED-5047': 1,
#   'MED-5048': 1,
#   'MED-5049': 1,
#   'MED-5050': 1,
#   'MED-5140': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5342': 1},
#  {'MED-4474': 1,
#   'MED-4475': 1,
#   'MED-4476': 1,
#   'MED-4477': 1,
#   'MED-4479': 1,
#   'MED-4480': 1,
#   'MED-4481': 1,
#   'MED-4482': 1,
#   'MED-4483': 1,
#   'MED-4484': 1,
#   'MED-4485': 1,
#   'MED-4486': 1,
#   'MED-4487': 1,
#   'MED-4488': 1,
#   'MED-4489': 1,
#   'MED-4490': 1,
#   'MED-4491': 1,
#   'MED-4492': 1,
#   'MED-4739': 1,
#   'MED-4740': 1,
#   'MED-4741': 1,
#   'MED-4747': 1,
#   'MED-4748': 1,
#   'MED-4749': 1,
#   'MED-4750': 1,
#   'MED-4751': 1,
#   'MED-4804': 1,
#   'MED-5072': 1,
#   'MED-5069': 1,
#   'MED-5070': 1,
#   'MED-5071': 1,
#   'MED-5167': 1,
#   'MED-5168': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-5176': 1,
#   'MED-4230': 1,
#   'MED-4231': 1,
#   'MED-4232': 1,
#   'MED-4233': 1,
#   'MED-4234': 1,
#   'MED-4235': 1,
#   'MED-4236': 1,
#   'MED-4237': 1,
#   'MED-4239': 1,
#   'MED-5322': 1,
#   'MED-5323': 1,
#   'MED-5324': 1,
#   'MED-5325': 1,
#   'MED-5326': 1,
#   'MED-5327': 1,
#   'MED-5328': 1,
#   'MED-5329': 1,
#   'MED-5330': 1,
#   'MED-5331': 1,
#   'MED-5332': 1,
#   'MED-5333': 1,
#   'MED-5334': 1,
#   'MED-5335': 1,
#   'MED-5363': 1,
#   'MED-5337': 1,
#   'MED-5338': 1,
#   'MED-5339': 1,
#   'MED-5340': 1,
#   'MED-5341': 1,
#   'MED-5342': 1},
#  {'MED-4295': 1,
#   'MED-4846': 1,
#   'MED-4296': 1,
#   'MED-4298': 1,
#   'MED-4300': 1,
#   'MED-4301': 1,
#   'MED-4637': 1,
#   'MED-4638': 1,
#   'MED-4639': 1,
#   'MED-4640': 1,
#   'MED-4641': 1,
#   'MED-4642': 1,
#   'MED-4643': 1,
#   'MED-4644': 1},
#  {'MED-4328': 1,
#   'MED-4329': 1,
#   'MED-4330': 1,
#   'MED-4331': 1,
#   'MED-4332': 1,
#   'MED-4415': 1,
#   'MED-4416': 1,
#   'MED-4417': 1,
#   'MED-4418': 1,
#   'MED-4419': 1,
#   'MED-5165': 1,
#   'MED-4421': 1,
#   'MED-4422': 1,
#   'MED-4438': 1,
#   'MED-4439': 1,
#   'MED-4471': 1,
#   'MED-4472': 1,
#   'MED-4976': 1,
#   'MED-4543': 1,
#   'MED-4538': 1,
#   'MED-4539': 1,
#   'MED-4540': 1,
#   'MED-4541': 1,
#   'MED-4602': 1,
#   'MED-4671': 1,
#   'MED-4775': 1,
#   'MED-4867': 1,
#   'MED-4868': 1,
#   'MED-4869': 1,
#   'MED-4877': 1,
#   'MED-4878': 1,
#   'MED-4879': 1,
#   'MED-4886': 1,
#   'MED-4887': 1,
#   'MED-4888': 1,
#   'MED-5337': 1,
#   'MED-4890': 1,
#   'MED-4891': 1,
#   'MED-5046': 1,
#   'MED-5047': 1,
#   'MED-5048': 1,
#   'MED-5049': 1,
#   'MED-5050': 1,
#   'MED-5052': 1,
#   'MED-5058': 1,
#   'MED-5064': 1,
#   'MED-5065': 1,
#   'MED-5176': 1,
#   'MED-5177': 1,
#   'MED-5178': 1,
#   'MED-5179': 1,
#   'MED-5184': 1},
#  {'MED-4375': 1,
#   'MED-4376': 1,
#   'MED-4378': 1,
#   'MED-4379': 1,
#   'MED-4380': 1,
#   'MED-4381': 1,
#   'MED-4531': 1,
#   'MED-4546': 1,
#   'MED-4547': 1,
#   'MED-4622': 1,
#   'MED-4736': 1,
#   'MED-4739': 1,
#   'MED-4738': 1,
#   'MED-4946': 1,
#   'MED-4951': 1,
#   'MED-5097': 1,
#   'MED-5098': 1,
#   'MED-5099': 1,
#   'MED-5100': 1,
#   'MED-5101': 1},
#  {'MED-4516': 1,
#   'MED-4517': 1,
#   'MED-4518': 1,
#   'MED-4522': 1,
#   'MED-4635': 1,
#   'MED-4640': 1,
#   'MED-4637': 1,
#   'MED-4638': 1,
#   'MED-4639': 1,
#   'MED-4641': 1,
#   'MED-4642': 1,
#   'MED-4643': 1,
#   'MED-4644': 1},
#  {'MED-906': 2, 'MED-4936': 1, 'MED-4932': 1},
#  {'MED-3714': 2, 'MED-917': 2, 'MED-4545': 1},
#  {'MED-927': 2,
#   'MED-928': 2,
#   'MED-4936': 2,
#   'MED-930': 2,
#   'MED-931': 2,
#   'MED-5091': 1,
#   'MED-5092': 1,
#   'MED-5093': 1},
#  {'MED-941': 2, 'MED-942': 2, 'MED-4701': 1, 'MED-4702': 1, 'MED-4703': 1},
#  {'MED-952': 2, 'MED-5159': 1, 'MED-5160': 1, 'MED-5161': 1, 'MED-5162': 1},
#  {'MED-961': 2,
#   'MED-962': 2,
#   'MED-5128': 1,
#   'MED-5129': 1,
#   'MED-5130': 1,
#   'MED-5131': 1,
#   'MED-5132': 1,
#   'MED-5133': 1,
#   'MED-5134': 1,
#   'MED-5135': 1},
#  {'MED-4222': 1},
#  {'MED-1796': 1,
#   'MED-1797': 1,
#   'MED-1798': 1,
#   'MED-1799': 1,
#   'MED-1800': 1,
#   'MED-1801': 1,
#   'MED-1802': 1,
#   'MED-1803': 1,
#   'MED-1804': 1,
#   'MED-4767': 1,
#   'MED-1806': 1,
#   'MED-1807': 1,
#   'MED-1808': 1,
#   'MED-4769': 1,
#   'MED-1810': 1},
#  {'MED-2896': 1,
#   'MED-2899': 1,
#   'MED-2900': 1,
#   'MED-2901': 1,
#   'MED-1103': 1,
#   'MED-1104': 1,
#   'MED-1105': 1,
#   'MED-1106': 1,
#   'MED-1107': 1,
#   'MED-1108': 1,
#   'MED-1109': 1,
#   'MED-1110': 1,
#   'MED-1111': 1,
#   'MED-1112': 1,
#   'MED-1113': 1,
#   'MED-1114': 1,
#   'MED-1115': 1,
#   'MED-2211': 1,
#   'MED-2212': 1,
#   'MED-2213': 1,
#   'MED-2214': 1,
#   'MED-2215': 1,
#   'MED-2216': 1,
#   'MED-2217': 1,
#   'MED-2218': 1,
#   'MED-4384': 1,
#   'MED-2898': 1,
#   'MED-3874': 1,
#   'MED-3875': 1,
#   'MED-3876': 1,
#   'MED-3877': 1,
#   'MED-3878': 1,
#   'MED-4233': 1,
#   'MED-4095': 1},
#  {'MED-3617': 1,
#   'MED-3618': 1,
#   'MED-3620': 1,
#   'MED-3621': 1,
#   'MED-3615': 1,
#   'MED-3622': 1},
#  {'MED-5155': 1},
#  {'MED-2527': 1,
#   'MED-2706': 1,
#   'MED-2708': 1,
#   'MED-2707': 1,
#   'MED-2711': 1,
#   'MED-2712': 1,
#   'MED-2713': 1,
#   'MED-2709': 1,
#   'MED-2710': 1,
#   'MED-2780': 1,
#   'MED-2810': 1,
#   'MED-2787': 1,
#   'MED-2788': 1,
#   'MED-2777': 1,
#   'MED-2816': 1,
#   'MED-2790': 1,
#   'MED-2792': 1,
#   'MED-2793': 1,
#   'MED-2794': 1,
#   'MED-4390': 1,
#   'MED-2797': 1,
#   'MED-2809': 1,
#   'MED-2799': 1,
#   'MED-2800': 1,
#   'MED-2801': 1,
#   'MED-2802': 1,
#   'MED-2803': 1,
#   'MED-2804': 1,
#   'MED-2805': 1,
#   'MED-2807': 1,
#   'MED-2526': 1,
#   'MED-2714': 1,
#   'MED-2781': 1,
#   'MED-2782': 1,
#   'MED-2818': 1,
#   'MED-2785': 1,
#   'MED-2791': 1,
#   'MED-2825': 1,
#   'MED-2819': 1,
#   'MED-2808': 1,
#   'MED-2811': 1,
#   'MED-2812': 1,
#   'MED-2817': 1,
#   'MED-2820': 1,
#   'MED-2821': 1,
#   'MED-2824': 1,
#   'MED-2831': 1,
#   'MED-3144': 1,
#   'MED-3459': 1,
#   'MED-3515': 1,
#   'MED-3516': 1,
#   'MED-3517': 1,
#   'MED-3536': 1,
#   'MED-3537': 1,
#   'MED-3538': 1,
#   'MED-3539': 1,
#   'MED-3540': 1,
#   'MED-3541': 1,
#   'MED-3542': 1,
#   'MED-3543': 1,
#   'MED-3544': 1,
#   'MED-3545': 1,
#   'MED-3546': 1,
#   'MED-3547': 1,
#   'MED-3658': 1,
#   'MED-3659': 1,
#   'MED-3660': 1,
#   'MED-3661': 1,
#   'MED-3662': 1,
#   'MED-3663': 1,
#   'MED-3664': 1,
#   'MED-3688': 1,
#   'MED-3689': 1,
#   'MED-3690': 1,
#   'MED-3691': 1,
#   'MED-3692': 1,
#   'MED-3693': 1,
#   'MED-3694': 1,
#   'MED-3695': 1,
#   'MED-3749': 1,
#   'MED-3750': 1,
#   'MED-3751': 1,
#   'MED-3752': 1,
#   'MED-3753': 1,
#   'MED-3754': 1,
#   'MED-3755': 1,
#   'MED-3756': 1,
#   'MED-3757': 1,
#   'MED-3758': 1,
#   'MED-3759': 1,
#   'MED-3760': 1,
#   'MED-3761': 1,
#   'MED-3796': 1,
#   'MED-3778': 1,
#   'MED-3779': 1,
#   'MED-3791': 1,
#   'MED-3792': 1,
#   'MED-3793': 1,
#   'MED-3794': 1,
#   'MED-3795': 1,
#   'MED-3797': 1,
#   'MED-3798': 1,
#   'MED-3799': 1,
#   'MED-3800': 1,
#   'MED-3801': 1,
#   'MED-3866': 1,
#   'MED-3867': 1,
#   'MED-3868': 1,
#   'MED-3869': 1,
#   'MED-3876': 1,
#   'MED-3877': 1,
#   'MED-3874': 1,
#   'MED-3878': 1,
#   'MED-3875': 1,
#   'MED-4233': 1,
#   'MED-3904': 1,
#   'MED-5175': 1,
#   'MED-4156': 1,
#   'MED-4157': 1,
#   'MED-4158': 1,
#   'MED-4159': 1,
#   'MED-4160': 1,
#   'MED-4161': 1,
#   'MED-4162': 1,
#   'MED-4188': 1,
#   'MED-4193': 1,
#   'MED-4192': 1,
#   'MED-4309': 1,
#   'MED-4312': 1,
#   'MED-4328': 1,
#   'MED-4329': 1,
#   'MED-4330': 1,
#   'MED-4365': 1,
#   'MED-4366': 1,
#   'MED-4370': 1,
#   'MED-4371': 1,
#   'MED-4369': 1,
#   'MED-4372': 1,
#   'MED-4373': 1,
#   'MED-4374': 1,
#   'MED-4533': 1,
#   'MED-4529': 1,
#   'MED-4535': 1,
#   'MED-4531': 1,
#   'MED-4532': 1,
#   'MED-4534': 1,
#   'MED-4536': 1,
#   'MED-4539': 1,
#   'MED-4540': 1,
#   'MED-4541': 1,
#   'MED-4543': 1,
#   'MED-4544': 1,
#   'MED-4563': 1,
#   'MED-4564': 1,
#   'MED-4565': 1,
#   'MED-4595': 1,
#   'MED-4669': 1,
#   'MED-4671': 1,
#   'MED-4711': 1,
#   'MED-4840': 1,
#   'MED-4842': 1,
#   'MED-4855': 1,
#   'MED-4856': 1,
#   'MED-4864': 1,
#   'MED-4870': 1,
#   'MED-4872': 1,
#   'MED-4873': 1,
#   'MED-4874': 1,
#   'MED-4876': 1,
#   'MED-4930': 1,
#   'MED-5022': 1,
#   'MED-5023': 1,
#   'MED-5024': 1,
#   'MED-5025': 1,
#   'MED-5029': 1,
#   'MED-5062': 1,
#   'MED-5063': 1,
#   'MED-5122': 1,
#   'MED-5120': 1,
#   'MED-5121': 1,
#   'MED-5157': 1,
#   'MED-5158': 1,
#   'MED-5172': 1,
#   'MED-5173': 1,
#   'MED-5176': 1,
#   'MED-5177': 1,
#   'MED-5178': 1,
#   'MED-5179': 1,
#   'MED-5184': 1},
#  {'MED-3618': 1,
#   'MED-3621': 1,
#   'MED-3617': 1,
#   'MED-3619': 1,
#   'MED-3620': 1,
#   'MED-3622': 1},
#  {'MED-4380': 1, 'MED-4381': 1},
#  {'MED-4422': 1,
#   'MED-3169': 1,
#   'MED-3170': 1,
#   'MED-3171': 1,
#   'MED-3172': 1,
#   'MED-3173': 1,
#   'MED-3174': 1,
#   'MED-3175': 1,
#   'MED-3176': 1,
#   'MED-3177': 1,
#   'MED-3178': 1,
#   'MED-3179': 1,
#   'MED-3180': 1,
#   'MED-3181': 1,
#   'MED-3182': 1,
#   'MED-3255': 1,
#   'MED-3540': 1,
#   'MED-3541': 1,
#   'MED-3542': 1,
#   'MED-3543': 1,
#   'MED-3544': 1,
#   'MED-3545': 1,
#   'MED-3546': 1,
#   'MED-3547': 1,
#   'MED-4555': 1},
#  {'MED-2337': 1,
#   'MED-2338': 1,
#   'MED-2340': 1,
#   'MED-2355': 1,
#   'MED-2349': 1,
#   'MED-4742': 1,
#   'MED-4743': 1},
#  {'MED-2575': 1,
#   'MED-2580': 1,
#   'MED-2571': 1,
#   'MED-2583': 1,
#   'MED-2574': 1,
#   'MED-2568': 1,
#   'MED-2988': 1,
#   'MED-2559': 1,
#   'MED-4319': 1,
#   'MED-2570': 1,
#   'MED-2573': 1,
#   'MED-2585': 1,
#   'MED-2980': 1,
#   'MED-2990': 1,
#   'MED-2986': 1,
#   'MED-2985': 1,
#   'MED-2987': 1,
#   'MED-2572': 1,
#   'MED-2577': 1,
#   'MED-2578': 1,
#   'MED-2579': 1,
#   'MED-2544': 1,
#   'MED-2581': 1,
#   'MED-2546': 1,
#   'MED-2584': 1,
#   'MED-2582': 1,
#   'MED-2979': 1,
#   'MED-2982': 1,
#   'MED-2983': 1,
#   'MED-2984': 1,
#   'MED-2989': 1,
#   'MED-3085': 1,
#   'MED-3086': 1,
#   'MED-3087': 1,
#   'MED-3088': 1,
#   'MED-3089': 1,
#   'MED-3090': 1,
#   'MED-3091': 1,
#   'MED-3092': 1,
#   'MED-3093': 1,
#   'MED-3094': 1,
#   'MED-3095': 1,
#   'MED-3096': 1,
#   'MED-4320': 1},
#  {'MED-4399': 1, 'MED-4400': 1, 'MED-4402': 1},
#  {'MED-4413': 1},
#  {'MED-1195': 1,
#   'MED-1196': 1,
#   'MED-5360': 1,
#   'MED-1198': 1,
#   'MED-1199': 1,
#   'MED-1200': 1,
#   'MED-1201': 1,
#   'MED-1202': 1,
#   'MED-1203': 1,
#   'MED-4488': 1},
#  {'MED-2522': 1,
#   'MED-2586': 1,
#   'MED-2587': 1,
#   'MED-2588': 1,
#   'MED-2591': 1,
#   'MED-3780': 1,
#   'MED-3784': 1,
#   'MED-1551': 1,
#   'MED-1552': 1,
#   'MED-1553': 1,
#   'MED-1554': 1,
#   'MED-1555': 1,
#   'MED-1556': 1,
#   'MED-1609': 1,
#   'MED-1610': 1,
#   'MED-1611': 1,
#   'MED-1612': 1,
#   'MED-1613': 1,
#   'MED-1614': 1,
#   'MED-1615': 1,
#   'MED-1616': 1,
#   'MED-1617': 1,
#   'MED-1618': 1,
#   'MED-1619': 1,
#   'MED-1620': 1,
#   'MED-2523': 1,
#   'MED-2589': 1,
#   'MED-2590': 1,
#   'MED-3786': 1,
#   'MED-3781': 1,
#   'MED-3789': 1,
#   'MED-3193': 1,
#   'MED-3783': 1,
#   'MED-3785': 1,
#   'MED-4514': 1,
#   'MED-4515': 1,
#   'MED-4880': 1,
#   'MED-4881': 1,
#   'MED-4882': 1,
#   'MED-4883': 1,
#   'MED-4884': 1},
#  {'MED-1463': 1,
#   'MED-1454': 1,
#   'MED-1455': 1,
#   'MED-1456': 1,
#   'MED-1457': 1,
#   'MED-1458': 1,
#   'MED-1459': 1,
#   'MED-1460': 1,
#   'MED-1461': 1,
#   'MED-1474': 1,
#   'MED-4514': 1,
#   'MED-4515': 1,
#   'MED-4618': 1,
#   'MED-4619': 1,
#   'MED-4620': 1,
#   'MED-4621': 1,
#   'MED-4673': 1,
#   'MED-4674': 1,
#   'MED-5153': 1,
#   'MED-5169': 1,
#   'MED-5170': 1},
#  {'MED-3146': 1,
#   'MED-3145': 1,
#   'MED-2033': 1,
#   'MED-2013': 1,
#   'MED-2014': 1,
#   'MED-2027': 1,
#   'MED-2016': 1,
#   'MED-2037': 1,
#   'MED-2018': 1,
#   'MED-2019': 1,
#   'MED-2020': 1,
#   'MED-2021': 1,
#   'MED-2022': 1,
#   'MED-2024': 1,
#   'MED-2034': 1,
#   'MED-2026': 1,
#   'MED-2028': 1,
#   'MED-2029': 1,
#   'MED-2030': 1,
#   'MED-2031': 1,
#   'MED-2032': 1,
#   'MED-2035': 1,
#   'MED-2036': 1,
#   'MED-2038': 1,
#   'MED-2039': 1,
#   'MED-2040': 1,
#   'MED-2041': 1,
#   'MED-3144': 1,
#   'MED-5154': 1},
#  {'MED-2513': 1,
#   'MED-2502': 1,
#   'MED-2498': 1,
#   'MED-2504': 1,
#   'MED-2505': 1,
#   'MED-2507': 1,
#   'MED-5239': 1,
#   'MED-2509': 1,
#   'MED-2519': 1,
#   'MED-2510': 1,
#   'MED-2511': 1,
#   'MED-2575': 1,
#   'MED-2580': 1,
#   'MED-2571': 1,
#   'MED-2583': 1,
#   'MED-2574': 1,
#   'MED-2568': 1,
#   'MED-2988': 1,
#   'MED-2559': 1,
#   'MED-4319': 1,
#   'MED-2570': 1,
#   'MED-2573': 1,
#   'MED-2585': 1,
#   'MED-2824': 1,
#   'MED-2815': 1,
#   'MED-2794': 1,
#   'MED-2816': 1,
#   'MED-2999': 1,
#   'MED-2997': 1,
#   'MED-2765': 1,
#   'MED-3001': 1,
#   'MED-2797': 1,
#   'MED-2809': 1,
#   'MED-2799': 1,
#   'MED-2800': 1,
#   'MED-2801': 1,
#   'MED-2802': 1,
#   'MED-2803': 1,
#   'MED-2804': 1,
#   'MED-2805': 1,
#   'MED-2807': 1,
#   'MED-2966': 1,
#   'MED-2968': 1,
#   'MED-2970': 1,
#   'MED-2972': 1,
#   'MED-4981': 1,
#   'MED-2980': 1,
#   'MED-2990': 1,
#   'MED-2986': 1,
#   'MED-2985': 1,
#   'MED-2987': 1,
#   'MED-717': 1,
#   'MED-718': 1,
#   'MED-719': 1,
#   'MED-720': 1,
#   'MED-721': 1,
#   'MED-722': 1,
#   'MED-723': 1,
#   'MED-724': 1,
#   'MED-5204': 1,
#   'MED-1184': 1,
#   'MED-1185': 1,
#   'MED-1186': 1,
#   'MED-1187': 1,
#   'MED-1188': 1,
#   'MED-1582': 1,
#   'MED-1190': 1,
#   'MED-5293': 1,
#   'MED-1192': 1,
#   'MED-1193': 1,
#   'MED-1194': 1,
#   'MED-1195': 1,
#   'MED-1196': 1,
#   'MED-5360': 1,
#   'MED-1198': 1,
#   'MED-1199': 1,
#   'MED-1200': 1,
#   'MED-1201': 1,
#   'MED-1202': 1,
#   'MED-1203': 1,
#   'MED-1231': 1,
#   'MED-1232': 1,
#   'MED-1233': 1,
#   'MED-1234': 1,
#   'MED-1375': 1,
#   'MED-1362': 1,
#   'MED-1363': 1,
#   'MED-1383': 1,
#   'MED-1365': 1,
#   'MED-1366': 1,
#   'MED-1643': 1,
#   'MED-1374': 1,
#   'MED-1380': 1,
#   'MED-5301': 1,
#   'MED-1371': 1,
#   'MED-5271': 1,
#   'MED-1373': 1,
#   'MED-1376': 1,
#   'MED-1377': 1,
#   'MED-1378': 1,
#   'MED-1401': 1,
#   'MED-1402': 1,
#   'MED-1403': 1,
#   'MED-1404': 1,
#   'MED-1405': 1,
#   'MED-1406': 1,
#   'MED-1407': 1,
#   'MED-1408': 1,
#   'MED-1409': 1,
#   'MED-1410': 1,
#   'MED-1411': 1,
#   'MED-1412': 1,
#   'MED-1413': 1,
#   'MED-1414': 1,
#   'MED-1415': 1,
#   'MED-1416': 1,
#   'MED-1417': 1,
#   'MED-1445': 1,
#   'MED-1446': 1,
#   'MED-1447': 1,
#   'MED-1448': 1,
#   'MED-1449': 1,
#   'MED-1450': 1,
#   'MED-1451': 1,
#   'MED-1527': 1,
#   'MED-1528': 1,
#   'MED-1529': 1,
#   'MED-1530': 1,
#   'MED-1531': 1,
#   'MED-2424': 1,
#   'MED-4451': 1,
#   'MED-2426': 1,
#   'MED-2445': 1,
#   'MED-2446': 1,
#   'MED-2458': 1,
#   'MED-2448': 1,
#   'MED-2449': 1,
#   'MED-2450': 1,
#   'MED-2451': 1,
#   'MED-2452': 1,
#   'MED-2453': 1,
#   'MED-2472': 1,
#   'MED-2488': 1,
#   'MED-2517': 1,
#   'MED-2501': 1,
#   'MED-2506': 1,
#   'MED-2512': 1,
#   'MED-2572': 1,
#   'MED-2577': 1,
#   'MED-2578': 1,
#   'MED-2579': 1,
#   'MED-2544': 1,
#   'MED-2581': 1,
#   'MED-2546': 1,
#   'MED-2584': 1,
#   'MED-2582': 1,
#   'MED-2820': 1,
#   'MED-3000': 1,
#   'MED-2819': 1,
#   'MED-4523': 1,
#   'MED-2967': 1,
#   'MED-2969': 1,
#   'MED-2971': 1,
#   'MED-2979': 1,
#   'MED-2982': 1,
#   'MED-2983': 1,
#   'MED-2984': 1,
#   'MED-2989': 1,
#   'MED-3109': 1,
#   'MED-3098': 1,
#   'MED-3099': 1,
#   'MED-3100': 1,
#   'MED-3112': 1,
#   'MED-3102': 1,
#   'MED-3138': 1,
#   'MED-3139': 1,
#   'MED-3140': 1,
#   'MED-3141': 1,
#   'MED-3142': 1,
#   'MED-3143': 1,
#   'MED-3136': 1,
#   'MED-3123': 1,
#   'MED-3127': 1,
#   'MED-3129': 1,
#   'MED-3130': 1,
#   'MED-3132': 1,
#   'MED-3135': 1,
#   'MED-3156': 1,
#   'MED-3157': 1,
#   'MED-3158': 1,
#   'MED-3450': 1,
#   'MED-3451': 1,
#   'MED-3161': 1,
#   'MED-3454': 1,
#   'MED-3163': 1,
#   'MED-3164': 1,
#   'MED-3165': 1,
#   'MED-3166': 1,
#   'MED-3466': 1,
#   'MED-3168': 1,
#   'MED-3232': 1,
#   'MED-3235': 1,
#   'MED-3270': 1,
#   'MED-3271': 1,
#   'MED-3272': 1,
#   'MED-3273': 1,
#   'MED-3274': 1,
#   'MED-3275': 1,
#   'MED-3276': 1,
#   'MED-3277': 1,
#   'MED-3278': 1,
#   'MED-3279': 1,
#   'MED-3280': 1,
#   'MED-3281': 1,
#   'MED-3282': 1,
#   'MED-3283': 1,
#   'MED-3369': 1,
#   'MED-3348': 1,
#   'MED-3371': 1,
#   'MED-3350': 1,
#   'MED-3351': 1,
#   'MED-3352': 1,
#   'MED-3353': 1,
#   'MED-3354': 1,
#   'MED-3355': 1,
#   'MED-3356': 1,
#   'MED-3373': 1,
#   'MED-3358': 1,
#   'MED-3359': 1,
#   'MED-3370': 1,
#   'MED-3372': 1,
#   'MED-3374': 1,
#   'MED-3375': 1,
#   'MED-3376': 1,
#   'MED-3377': 1,
#   'MED-3422': 1,
#   'MED-3425': 1,
#   'MED-3426': 1,
#   'MED-3428': 1,
#   'MED-3407': 1,
#   'MED-3429': 1,
#   'MED-3433': 1,
#   'MED-3434': 1,
#   'MED-3435': 1,
#   'MED-3437': 1,
#   'MED-3438': 1,
#   'MED-3417': 1,
#   'MED-3439': 1,
#   'MED-3440': 1,
#   'MED-3420': 1,
#   'MED-3421': 1,
#   'MED-3548': 1,
#   'MED-3549': 1,
#   'MED-3550': 1,
#   'MED-3551': 1,
#   'MED-3552': 1,
#   'MED-3553': 1,
#   'MED-3554': 1,
#   'MED-3555': 1,
#   'MED-3580': 1,
#   'MED-3581': 1,
#   'MED-3582': 1,
#   'MED-3583': 1,
#   'MED-3584': 1,
#   'MED-3769': 1,
#   'MED-3770': 1,
#   'MED-3780': 1,
#   'MED-3781': 1,
#   'MED-3782': 1,
#   'MED-3783': 1,
#   'MED-3784': 1,
#   'MED-3785': 1,
#   'MED-3786': 1,
#   'MED-3787': 1,
#   'MED-3788': 1,
#   'MED-3789': 1,
#   'MED-3790': 1,
#   'MED-3815': 1,
#   'MED-3816': 1,
#   'MED-3817': 1,
#   'MED-3818': 1,
#   'MED-3819': 1,
#   'MED-3820': 1,
#   'MED-3821': 1,
#   'MED-3822': 1,
#   'MED-3858': 1,
#   'MED-4094': 1,
#   'MED-3860': 1,
#   'MED-4313': 1,
#   'MED-3862': 1,
#   'MED-3925': 1,
#   'MED-3926': 1,
#   'MED-3927': 1,
#   'MED-3928': 1,
#   'MED-3929': 1,
#   'MED-3930': 1,
#   'MED-3931': 1,
#   'MED-3932': 1,
#   'MED-3933': 1,
#   'MED-4106': 1,
#   'MED-4165': 1,
#   'MED-4216': 1,
#   'MED-4211': 1,
#   'MED-4212': 1,
#   'MED-4886': 1,
#   'MED-5176': 1,
#   'MED-4230': 1,
#   'MED-4231': 1,
#   'MED-4232': 1,
#   'MED-4233': 1,
#   'MED-4234': 1,
#   'MED-4245': 1,
#   'MED-4246': 1,
#   'MED-4247': 1,
#   'MED-4255': 1,
#   'MED-4281': 1,
#   'MED-4314': 1,
#   'MED-4315': 1,
#   'MED-4320': 1,
#   'MED-4347': 1,
#   'MED-4627': 1,
#   'MED-4349': 1,
#   'MED-4350': 1,
#   'MED-4406': 1,
#   'MED-4509': 1,
#   'MED-4510': 1,
#   'MED-4581': 1,
#   'MED-4582': 1,
#   'MED-4583': 1,
#   'MED-4600': 1,
#   'MED-4686': 1,
#   'MED-4689': 1,
#   'MED-4727': 1,
#   'MED-4728': 1,
#   'MED-4771': 1,
#   'MED-4863': 1,
#   'MED-4952': 1,
#   'MED-4953': 1,
#   'MED-4954': 1,
#   'MED-4991': 1,
#   'MED-4992': 1,
#   'MED-5002': 1,
#   'MED-5003': 1,
#   'MED-5004': 1,
#   'MED-5072': 1,
#   'MED-5069': 1,
#   'MED-5070': 1,
#   'MED-5071': 1,
#   'MED-5078': 1,
#   'MED-5079': 1,
#   'MED-5080': 1,
#   'MED-5111': 1,
#   'MED-5159': 1,
#   'MED-5160': 1,
#   'MED-5161': 1,
#   'MED-5162': 1},
#  {'MED-4857': 1},
#  {'MED-5017': 1},
#  {'MED-1847': 1,
#   'MED-1848': 1,
#   'MED-1849': 1,
#   'MED-1850': 1,
#   'MED-1851': 1,
#   'MED-1852': 1,
#   'MED-2185': 1,
#   'MED-2200': 1,
#   'MED-2201': 1,
#   'MED-2188': 1,
#   'MED-2189': 1,
#   'MED-2202': 1,
#   'MED-2191': 1,
#   'MED-2203': 1,
#   'MED-2204': 1,
#   'MED-2194': 1,
#   'MED-2195': 1,
#   'MED-2208': 1,
#   'MED-2207': 1,
#   'MED-2209': 1,
#   'MED-2210': 1},
#  {'MED-3714': 1,
#   'MED-3720': 1,
#   'MED-3721': 1,
#   'MED-3715': 1,
#   'MED-3716': 1,
#   'MED-3717': 1,
#   'MED-3718': 1,
#   'MED-3719': 1},
#  {'MED-398': 1,
#   'MED-3200': 1,
#   'MED-3201': 1,
#   'MED-3202': 1,
#   'MED-3203': 1,
#   'MED-3209': 1,
#   'MED-1682': 1,
#   'MED-1683': 1,
#   'MED-1701': 1,
#   'MED-1685': 1,
#   'MED-1686': 1,
#   'MED-1687': 1,
#   'MED-1688': 1,
#   'MED-1689': 1,
#   'MED-1690': 1,
#   'MED-1691': 1,
#   'MED-2077': 1,
#   'MED-1693': 1,
#   'MED-2078': 1,
#   'MED-1695': 1,
#   'MED-1696': 1,
#   'MED-1697': 1,
#   'MED-3841': 1,
#   'MED-3843': 1,
#   'MED-3849': 1,
#   'MED-3830': 1,
#   'MED-1825': 1,
#   'MED-1826': 1,
#   'MED-1827': 1,
#   'MED-1828': 1,
#   'MED-1829': 1,
#   'MED-1830': 1,
#   'MED-2076': 1,
#   'MED-2079': 1,
#   'MED-2080': 1,
#   'MED-5293': 1,
#   'MED-2082': 1,
#   'MED-2083': 1,
#   'MED-5303': 1,
#   'MED-2085': 1,
#   'MED-3199': 1,
#   'MED-3204': 1,
#   'MED-3205': 1,
#   'MED-3206': 1,
#   'MED-3207': 1,
#   'MED-3208': 1,
#   'MED-3210': 1,
#   'MED-4352': 1,
#   'MED-4353': 1,
#   'MED-4649': 1,
#   'MED-4650': 1,
#   'MED-4651': 1,
#   'MED-4776': 1,
#   'MED-4777': 1,
#   'MED-4778': 1,
#   'MED-4779': 1,
#   'MED-4780': 1},
#  {'MED-1265': 1,
#   'MED-1266': 1,
#   'MED-1267': 1,
#   'MED-1268': 1,
#   'MED-1278': 1,
#   'MED-1282': 1,
#   'MED-1271': 1,
#   'MED-1272': 1,
#   'MED-1273': 1,
#   'MED-1274': 1,
#   'MED-1287': 1,
#   'MED-1276': 1,
#   'MED-1277': 1,
#   'MED-1279': 1,
#   'MED-1280': 1,
#   'MED-1281': 1,
#   'MED-1283': 1,
#   'MED-1284': 1,
#   'MED-1285': 1,
#   'MED-4876': 1,
#   'MED-1288': 1,
#   'MED-1289': 1,
#   'MED-1290': 1,
#   'MED-5172': 1,
#   'MED-5173': 1},
#  {'MED-2988': 1,
#   'MED-2980': 1,
#   'MED-2990': 1,
#   'MED-2986': 1,
#   'MED-2985': 1,
#   'MED-2987': 1,
#   'MED-332': 1,
#   'MED-3090': 1,
#   'MED-334': 1,
#   'MED-335': 1,
#   'MED-3092': 1,
#   'MED-3094': 1,
#   'MED-3226': 1,
#   'MED-3227': 1,
#   'MED-3230': 1,
#   'MED-3229': 1,
#   'MED-3232': 1,
#   'MED-3233': 1,
#   'MED-4722': 1,
#   'MED-3237': 1,
#   'MED-1337': 1,
#   'MED-1338': 1,
#   'MED-1339': 1,
#   'MED-1340': 1,
#   'MED-1341': 1,
#   'MED-1486': 1,
#   'MED-1487': 1,
#   'MED-1488': 1,
#   'MED-1489': 1,
#   'MED-1490': 1,
#   'MED-2979': 1,
#   'MED-4319': 1,
#   'MED-2982': 1,
#   'MED-2983': 1,
#   'MED-2984': 1,
#   'MED-2989': 1,
#   'MED-3085': 1,
#   'MED-3086': 1,
#   'MED-3087': 1,
#   'MED-3088': 1,
#   'MED-3089': 1,
#   'MED-3091': 1,
#   'MED-3093': 1,
#   'MED-3095': 1,
#   'MED-3096': 1,
#   'MED-3228': 1,
#   'MED-3231': 1,
#   'MED-3235': 1,
#   'MED-3236': 1,
#   'MED-4984': 1,
#   'MED-4985': 1,
#   'MED-4988': 1,
#   'MED-4987': 1,
#   'MED-5145': 1},
#  {'MED-3874': 1,
#   'MED-3875': 1,
#   'MED-3876': 1,
#   'MED-3877': 1,
#   'MED-3878': 1,
#   'MED-4233': 1,
#   'MED-5176': 1,
#   'MED-4230': 1,
#   'MED-4231': 1,
#   'MED-4232': 1,
#   'MED-4234': 1,
#   'MED-4235': 1,
#   'MED-4236': 1,
#   'MED-4237': 1,
#   'MED-4239': 1,
#   'MED-5177': 1,
#   'MED-5178': 1,
#   'MED-5179': 1,
#   'MED-5184': 1},
#  {'MED-3136': 1,
#   'MED-3123': 1,
#   'MED-3138': 1,
#   'MED-3143': 1,
#   'MED-3137': 1,
#   'MED-3132': 1,
#   'MED-3141': 1},
#  {'MED-3796': 1,
#   'MED-3778': 1,
#   'MED-3801': 1,
#   'MED-3794': 1,
#   'MED-666': 1,
#   'MED-3779': 1},
#  {'MED-3385': 1, 'MED-3387': 1, 'MED-3386': 1},
#  {'MED-4991': 1, 'MED-4992': 1},
#  {'MED-4546': 1,
#   'MED-4547': 1,
#   'MED-4958': 1,
#   'MED-4959': 1,
#   'MED-4960': 1,
#   'MED-4961': 1},
#  {'MED-2513': 1,
#   'MED-2502': 1,
#   'MED-2498': 1,
#   'MED-2504': 1,
#   'MED-2505': 1,
#   'MED-2507': 1,
#   'MED-5239': 1,
#   'MED-2509': 1,
#   'MED-2519': 1,
#   'MED-2510': 1,
#   'MED-2511': 1,
#   'MED-5237': 1,
#   'MED-2517': 1,
#   'MED-2518': 1,
#   'MED-2520': 1,
#   'MED-2521': 1,
#   'MED-3050': 1,
#   'MED-3038': 1,
#   'MED-3052': 1,
#   'MED-3053': 1,
#   'MED-3054': 1,
#   'MED-3044': 1,
#   'MED-3046': 1,
#   'MED-3058': 1,
#   'MED-3059': 1,
#   'MED-3060': 1,
#   'MED-3273': 1,
#   'MED-3276': 1,
#   'MED-3283': 1,
#   'MED-1711': 1,
#   'MED-1712': 1,
#   'MED-2763': 1,
#   'MED-1714': 1,
#   'MED-1715': 1,
#   'MED-1716': 1,
#   'MED-1717': 1,
#   'MED-1718': 1,
#   'MED-1719': 1,
#   'MED-1720': 1,
#   'MED-1721': 1,
#   'MED-1722': 1,
#   'MED-1723': 1,
#   'MED-1724': 1,
#   'MED-2127': 1,
#   'MED-2128': 1,
#   'MED-2129': 1,
#   'MED-2130': 1,
#   'MED-2132': 1,
#   'MED-2134': 1,
#   'MED-2135': 1,
#   'MED-2136': 1,
#   'MED-2137': 1,
#   'MED-2138': 1,
#   'MED-2139': 1,
#   'MED-2147': 1,
#   'MED-2148': 1,
#   'MED-2149': 1,
#   'MED-2324': 1,
#   'MED-2325': 1,
#   'MED-2326': 1,
#   'MED-2327': 1,
#   'MED-2328': 1,
#   'MED-2335': 1,
#   'MED-2330': 1,
#   'MED-2331': 1,
#   'MED-2441': 1,
#   'MED-2442': 1,
#   'MED-2472': 1,
#   'MED-2444': 1,
#   'MED-2501': 1,
#   'MED-2506': 1,
#   'MED-2512': 1,
#   'MED-2514': 1,
#   'MED-2943': 1,
#   'MED-3051': 1,
#   'MED-3055': 1,
#   'MED-3056': 1,
#   'MED-3057': 1,
#   'MED-3270': 1,
#   'MED-3271': 1,
#   'MED-3272': 1,
#   'MED-3274': 1,
#   'MED-3275': 1,
#   'MED-3277': 1,
#   'MED-3278': 1,
#   'MED-3279': 1,
#   'MED-3280': 1,
#   'MED-3281': 1,
#   'MED-3282': 1,
#   'MED-4120': 1,
#   'MED-4121': 1,
#   'MED-4124': 1,
#   'MED-4321': 1,
#   'MED-4322': 1,
#   'MED-4323': 1,
#   'MED-4996': 1},
#  {'MED-4841': 1},
#  {'MED-2568': 1,
#   'MED-2988': 1,
#   'MED-2559': 1,
#   'MED-4319': 1,
#   'MED-2570': 1,
#   'MED-2573': 1,
#   'MED-2574': 1,
#   'MED-2585': 1,
#   'MED-2599': 1,
#   'MED-2607': 1,
#   'MED-2602': 1,
#   'MED-2603': 1,
#   'MED-2605': 1,
#   'MED-2604': 1,
#   'MED-2606': 1,
#   'MED-2608': 1,
#   'MED-2816': 1,
#   'MED-4551': 1,
#   'MED-2643': 1,
#   'MED-2645': 1,
#   'MED-2656': 1,
#   'MED-2657': 1,
#   'MED-2658': 1,
#   'MED-2660': 1,
#   'MED-2649': 1,
#   'MED-2675': 1,
#   'MED-2676': 1,
#   'MED-2677': 1,
#   'MED-2678': 1,
#   'MED-2679': 1,
#   'MED-2992': 1,
#   'MED-2994': 1,
#   'MED-3781': 1,
#   'MED-3789': 1,
#   'MED-3790': 1,
#   'MED-3782': 1,
#   'MED-3762': 1,
#   'MED-3763': 1,
#   'MED-3764': 1,
#   'MED-1139': 1,
#   'MED-1140': 1,
#   'MED-1167': 1,
#   'MED-1142': 1,
#   'MED-1143': 1,
#   'MED-1144': 1,
#   'MED-1181': 1,
#   'MED-1146': 1,
#   'MED-1147': 1,
#   'MED-1763': 1,
#   'MED-1592': 1,
#   'MED-1593': 1,
#   'MED-1594': 1,
#   'MED-1595': 1,
#   'MED-1596': 1,
#   'MED-1597': 1,
#   'MED-1598': 1,
#   'MED-1599': 1,
#   'MED-1600': 1,
#   'MED-1601': 1,
#   'MED-1602': 1,
#   'MED-1603': 1,
#   'MED-1604': 1,
#   'MED-1605': 1,
#   'MED-1606': 1,
#   'MED-1607': 1,
#   'MED-4476': 1,
#   'MED-1811': 1,
#   'MED-1812': 1,
#   'MED-1813': 1,
#   'MED-1814': 1,
#   'MED-5190': 1,
#   'MED-4823': 1,
#   'MED-1817': 1,
#   'MED-1818': 1,
#   'MED-1819': 1,
#   'MED-1820': 1,
#   'MED-2086': 1,
#   'MED-2087': 1,
#   'MED-2088': 1,
#   'MED-2099': 1,
#   'MED-2100': 1,
#   'MED-2101': 1,
#   'MED-2102': 1,
#   'MED-2103': 1,
#   'MED-2529': 1,
#   'MED-2105': 1,
#   'MED-2106': 1,
#   'MED-2107': 1,
#   'MED-2108': 1,
#   'MED-2185': 1,
#   'MED-2200': 1,
#   'MED-2201': 1,
#   'MED-2188': 1,
#   'MED-2189': 1,
#   'MED-2202': 1,
#   'MED-2191': 1,
#   'MED-2203': 1,
#   'MED-2204': 1,
#   'MED-2194': 1,
#   'MED-2195': 1,
#   'MED-2208': 1,
#   'MED-2207': 1,
#   'MED-2209': 1,
#   'MED-2210': 1,
#   'MED-2414': 1,
#   'MED-4070': 1,
#   'MED-2416': 1,
#   'MED-2417': 1,
#   'MED-2418': 1,
#   'MED-3498': 1,
#   'MED-2420': 1,
#   'MED-2421': 1,
#   'MED-2422': 1,
#   'MED-2423': 1,
#   'MED-2424': 1,
#   'MED-4451': 1,
#   'MED-2426': 1,
#   'MED-2441': 1,
#   'MED-2442': 1,
#   'MED-2472': 1,
#   'MED-2444': 1,
#   'MED-2490': 1,
# ...
#  {'MED-4423': 2, 'MED-4424': 2},
#  {'MED-4436': 2, 'MED-4437': 2},
#  {'MED-4454': 2},
#  {'MED-4470': 2},
#  {'MED-4508': 2, 'MED-4504': 2, 'MED-4505': 2, 'MED-4506': 2},
#  {'MED-4525': 2, 'MED-4526': 2, 'MED-4527': 2},
#  {'MED-3742': 1, 'MED-3893': 1, 'MED-3894': 1, 'MED-4544': 1},
#  {'MED-4555': 2},
#  {'MED-4573': 2, 'MED-4570': 2},
#  {'MED-4590': 2, 'MED-4591': 2, 'MED-2215': 1, 'MED-726': 1},
#  {'MED-5331': 2},
#  {'MED-4619': 2,
#   'MED-4620': 2,
#   'MED-4621': 2,
#   'MED-4514': 1,
#   'MED-4515': 1,
#   'MED-4618': 1},
#  {'MED-4642': 2,
#   'MED-4643': 2,
#   'MED-4644': 2,
#   'MED-3762': 1,
#   'MED-3763': 1,
#   'MED-3764': 1,
#   'MED-1375': 1,
#   'MED-1362': 1,
#   'MED-1363': 1,
#   'MED-1383': 1,
#   'MED-1365': 1,
#   'MED-1366': 1,
#   'MED-1643': 1,
#   'MED-1374': 1,
#   'MED-1380': 1,
#   'MED-5301': 1,
#   'MED-1371': 1,
#   'MED-5271': 1,
#   'MED-1373': 1,
#   'MED-3841': 1,
#   'MED-3843': 1,
#   'MED-3849': 1,
#   'MED-3830': 1,
#   'MED-1825': 1,
#   'MED-1826': 1,
#   'MED-1827': 1,
#   'MED-1828': 1,
#   'MED-1829': 1,
#   'MED-1830': 1,
#   'MED-3858': 1,
#   'MED-4094': 1,
#   'MED-3860': 1,
#   'MED-4313': 1,
#   'MED-3862': 1},
#  {'MED-4660': 2,
#   'MED-4666': 2,
#   'MED-4662': 2,
#   'MED-4663': 2,
#   'MED-4664': 2,
#   'MED-3441': 1,
#   'MED-3442': 1,
#   'MED-3443': 1,
#   'MED-3444': 1,
#   'MED-3445': 1,
#   'MED-3446': 1,
#   'MED-3447': 1,
#   'MED-3448': 1,
#   'MED-3971': 1,
#   'MED-3972': 1,
#   'MED-3973': 1,
#   'MED-3974': 1,
#   'MED-3975': 1},
#  {'MED-4677': 2,
#   'MED-1223': 1,
#   'MED-1224': 1,
#   'MED-5239': 1,
#   'MED-1226': 1,
#   'MED-1227': 1,
#   'MED-2126': 1,
#   'MED-1229': 1,
#   'MED-1230': 1,
#   'MED-1337': 1,
#   'MED-1338': 1,
#   'MED-1339': 1,
#   'MED-1340': 1,
#   'MED-1341': 1,
#   'MED-1763': 1,
#   'MED-1584': 1,
#   'MED-1585': 1,
#   'MED-1586': 1,
#   'MED-1587': 1,
#   'MED-1588': 1,
#   'MED-1595': 1,
#   'MED-1596': 1,
#   'MED-1762': 1,
#   'MED-1764': 1,
#   'MED-1765': 1,
#   'MED-1766': 1,
#   'MED-1778': 1,
#   'MED-1768': 1,
#   'MED-4951': 1,
#   'MED-1770': 1,
#   'MED-1771': 1,
#   'MED-1781': 1,
#   'MED-1773': 1,
#   'MED-1774': 1,
#   'MED-4726': 1,
#   'MED-3935': 1,
#   'MED-3936': 1,
#   'MED-3937': 1,
#   'MED-3938': 1,
#   'MED-3939': 1,
#   'MED-3940': 1,
#   'MED-4398': 1,
#   'MED-4396': 1},
#  {'MED-4696': 2,
#   'MED-1486': 1,
#   'MED-1487': 1,
#   'MED-1488': 1,
#   'MED-1489': 1,
#   'MED-1490': 1,
#   'MED-1496': 1,
#   'MED-1497': 1,
#   'MED-1498': 1,
#   'MED-1499': 1,
#   'MED-1500': 1,
#   'MED-1501': 1,
#   'MED-1502': 1,
#   'MED-1503': 1,
#   'MED-1504': 1,
#   'MED-1505': 1,
#   'MED-1506': 1,
#   'MED-5328': 1,
#   'MED-1540': 1,
#   'MED-1541': 1,
#   'MED-1998': 1,
#   'MED-1985': 1,
#   'MED-1986': 1,
#   'MED-1987': 1,
#   'MED-1988': 1,
#   'MED-1999': 1,
#   'MED-1990': 1,
#   'MED-1991': 1,
#   'MED-1992': 1,
#   'MED-1993': 1,
#   'MED-1994': 1,
#   'MED-2221': 1,
#   'MED-1996': 1,
#   'MED-1997': 1},
#  {'MED-1574': 1,
#   'MED-1575': 1,
#   'MED-1576': 1,
#   'MED-1577': 1,
#   'MED-1578': 1,
#   'MED-1579': 1,
#   'MED-1580': 1,
#   'MED-1581': 1,
#   'MED-1582': 1,
#   'MED-1789': 1,
#   'MED-1790': 1,
#   'MED-1791': 1,
#   'MED-1792': 1,
#   'MED-1793': 1,
#   'MED-1794': 1,
#   'MED-1795': 1,
#   'MED-3780': 1,
#   'MED-3781': 1,
#   'MED-3782': 1,
#   'MED-3783': 1,
#   'MED-3784': 1,
#   'MED-3785': 1,
#   'MED-3786': 1,
#   'MED-3787': 1,
#   'MED-3788': 1,
#   'MED-3789': 1,
#   'MED-3790': 1},
#  {'MED-4729': 2,
#   'MED-4730': 2,
#   'MED-4731': 2,
#   'MED-4732': 2,
#   'MED-1831': 1,
#   'MED-1832': 1,
#   'MED-1833': 1,
#   'MED-1834': 1,
#   'MED-5092': 1,
#   'MED-2750': 1,
#   'MED-2751': 1,
#   'MED-2752': 1,
#   'MED-2753': 1,
#   'MED-2754': 1,
#   'MED-2755': 1,
#   'MED-2756': 1},
#  {'MED-4752': 2,
#   'MED-1223': 1,
#   'MED-1224': 1,
#   'MED-5239': 1,
#   'MED-1226': 1,
#   'MED-1227': 1,
#   'MED-2126': 1,
#   'MED-1229': 1,
#   'MED-1230': 1,
#   'MED-1337': 1,
#   'MED-1338': 1,
#   'MED-1339': 1,
#   'MED-1340': 1,
#   'MED-1341': 1,
#   'MED-1762': 1,
#   'MED-1763': 1,
#   'MED-1764': 1,
#   'MED-1765': 1,
#   'MED-1766': 1,
#   'MED-1778': 1,
#   'MED-1768': 1,
#   'MED-4951': 1,
#   'MED-1770': 1,
#   'MED-1771': 1,
#   'MED-1781': 1,
#   'MED-1773': 1,
#   'MED-1774': 1,
#   'MED-3597': 1,
#   'MED-3598': 1,
#   'MED-3599': 1,
#   'MED-5106': 1,
#   'MED-4398': 1},
#  {'MED-3810': 1,
#   'MED-3109': 1,
#   'MED-3098': 1,
#   'MED-3099': 1,
#   'MED-3100': 1,
#   'MED-3112': 1,
#   'MED-3102': 1,
#   'MED-3103': 1,
#   'MED-3709': 1,
#   'MED-3105': 1,
#   'MED-3106': 1,
#   'MED-3107': 1,
#   'MED-3108': 1,
#   'MED-3110': 1,
#   'MED-3111': 1,
#   'MED-4040': 1,
#   'MED-4976': 1,
#   'MED-5197': 1},
#  {'MED-4790': 2,
#   'MED-2215': 1,
#   'MED-726': 1,
#   'MED-4671': 1,
#   'MED-743': 1,
#   'MED-744': 1,
#   'MED-745': 1,
#   'MED-746': 1,
#   'MED-4193': 1,
#   'MED-3585': 1,
#   'MED-3586': 1,
#   'MED-3587': 1,
#   'MED-3588': 1,
#   'MED-3589': 1,
#   'MED-3590': 1,
#   'MED-3591': 1,
#   'MED-3592': 1,
#   'MED-3593': 1,
#   'MED-4954': 1,
#   'MED-3595': 1,
#   'MED-3596': 1,
#   'MED-4533': 1,
#   'MED-4529': 1,
#   'MED-4535': 1},
#  {'MED-4820': 2,
#   'MED-4821': 2,
#   'MED-4436': 1,
#   'MED-4437': 1,
#   'MED-5032': 1,
#   'MED-5033': 1,
#   'MED-5034': 1,
#   'MED-5035': 1},
#  {'MED-4841': 2,
#   'MED-1223': 1,
#   'MED-1224': 1,
#   'MED-5239': 1,
#   'MED-1226': 1,
#   'MED-1227': 1,
#   'MED-2126': 1,
#   'MED-1229': 1,
#   'MED-1230': 1,
#   'MED-2053': 1,
#   'MED-2054': 1,
#   'MED-2055': 1,
#   'MED-2056': 1,
#   'MED-2057': 1,
#   'MED-2058': 1,
#   'MED-2059': 1,
#   'MED-2060': 1,
#   'MED-2061': 1,
#   'MED-2062': 1,
#   'MED-2063': 1,
#   'MED-2769': 1,
#   'MED-2770': 1,
#   'MED-2771': 1,
#   'MED-2772': 1,
#   'MED-2773': 1,
#   'MED-2774': 1,
#   'MED-2775': 1,
#   'MED-4398': 1,
#   'MED-4396': 1},
#  {'MED-4861': 2,
#   'MED-4390': 1,
#   'MED-1559': 1,
#   'MED-1560': 1,
#   'MED-3557': 1,
#   'MED-3242': 1,
#   'MED-1563': 1,
#   'MED-1564': 1,
#   'MED-1565': 1,
#   'MED-3699': 1,
#   'MED-1567': 1,
#   'MED-3742': 1,
#   'MED-3743': 1,
#   'MED-3744': 1,
#   'MED-3745': 1,
#   'MED-3746': 1,
#   'MED-3747': 1,
#   'MED-3748': 1,
#   'MED-4089': 1,
#   'MED-4090': 1,
#   'MED-4095': 1},
#  {'MED-4872': 2,
#   'MED-4873': 2,
#   'MED-4874': 2,
#   'MED-3985': 1,
#   'MED-3986': 1,
#   'MED-3987': 1,
#   'MED-3988': 1,
#   'MED-3989': 1,
#   'MED-3990': 1,
#   'MED-3991': 1,
#   'MED-4566': 1,
#   'MED-4574': 1,
#   'MED-4575': 1},
#  {'MED-1527': 1,
#   'MED-1528': 1,
#   'MED-1529': 1,
#   'MED-1530': 1,
#   'MED-1531': 1,
#   'MED-1532': 1,
#   'MED-1559': 1,
#   'MED-1560': 1,
#   'MED-3557': 1,
#   'MED-3242': 1,
#   'MED-1563': 1,
#   'MED-1564': 1,
#   'MED-1565': 1,
#   'MED-3699': 1,
#   'MED-1567': 1,
#   'MED-1598': 1,
#   'MED-1599': 1,
#   'MED-1600': 1,
#   'MED-1601': 1,
#   'MED-1602': 1,
#   'MED-1603': 1,
#   'MED-1604': 1,
#   'MED-1605': 1,
#   'MED-1606': 1,
#   'MED-1607': 1,
#   'MED-4476': 1,
#   'MED-1609': 1,
#   'MED-1610': 1,
#   'MED-1611': 1,
#   'MED-1612': 1,
#   'MED-1613': 1,
#   'MED-1614': 1,
#   'MED-1615': 1,
#   'MED-1616': 1,
#   'MED-1617': 1,
#   'MED-1618': 1,
#   'MED-1619': 1,
#   'MED-1620': 1,
#   'MED-3780': 1,
#   'MED-3781': 1,
#   'MED-3782': 1,
#   'MED-3783': 1,
#   'MED-3784': 1,
#   'MED-3785': 1,
#   'MED-3786': 1,
#   'MED-3787': 1,
#   'MED-3788': 1,
#   'MED-3789': 1,
#   'MED-3790': 1},
#  {'MED-4908': 2,
#   'MED-4909': 2,
#   'MED-2248': 1,
#   'MED-2249': 1,
#   'MED-2250': 1,
#   'MED-2251': 1,
#   'MED-2252': 1,
#   'MED-2253': 1,
#   'MED-2254': 1,
#   'MED-2255': 1,
#   'MED-2256': 1,
#   'MED-2257': 1,
#   'MED-2258': 1,
#   'MED-2259': 1,
#   'MED-2260': 1,
#   'MED-2261': 1,
#   'MED-2262': 1,
#   'MED-2263': 1,
#   'MED-2264': 1,
#   'MED-4533': 1,
#   'MED-4529': 1,
#   'MED-4535': 1,
#   'MED-4531': 1,
#   'MED-4532': 1,
#   'MED-4534': 1,
#   'MED-4536': 1},
#  {'MED-4925': 2,
#   'MED-2759': 1,
#   'MED-2760': 1,
#   'MED-2761': 1,
#   'MED-4645': 1,
#   'MED-4646': 1,
#   'MED-4647': 1},
#  {'MED-4946': 2,
#   'MED-2385': 1,
#   'MED-2386': 1,
#   'MED-2395': 1,
#   'MED-2388': 1,
#   'MED-2389': 1,
#   'MED-2396': 1,
#   'MED-2391': 1,
#   'MED-2407': 1,
#   'MED-3021': 1,
#   'MED-3023': 1,
#   'MED-2904': 1,
#   'MED-2905': 1,
#   'MED-2906': 1,
#   'MED-2907': 1,
#   'MED-3024': 1,
#   'MED-3025': 1,
#   'MED-2910': 1,
#   'MED-3027': 1,
#   'MED-3028': 1,
#   'MED-2913': 1,
#   'MED-3012': 1,
#   'MED-3013': 1,
#   'MED-3030': 1,
#   'MED-2917': 1,
#   'MED-3033': 1,
#   'MED-3034': 1,
#   'MED-3035': 1,
#   'MED-2921': 1,
#   'MED-3019': 1,
#   'MED-3022': 1,
#   'MED-3026': 1,
#   'MED-3029': 1,
#   'MED-3032': 1,
#   'MED-3020': 1,
#   'MED-3031': 1,
#   'MED-4376': 1},
#  {'MED-4962': 2,
#   'MED-4963': 2,
#   'MED-4964': 2,
#   'MED-4969': 2,
#   'MED-4966': 2,
#   'MED-4967': 2,
#   'MED-4968': 2,
#   'MED-1568': 1,
#   'MED-1569': 1,
#   'MED-1570': 1,
#   'MED-1571': 1,
#   'MED-1572': 1,
#   'MED-1573': 1},
#  {'MED-2926': 1,
#   'MED-2922': 1,
#   'MED-3465': 1,
#   'MED-2923': 1,
#   'MED-2925': 1,
#   'MED-1527': 1,
#   'MED-1528': 1,
#   'MED-1529': 1,
#   'MED-1530': 1,
#   'MED-1531': 1,
#   'MED-1532': 1,
#   'MED-1559': 1,
#   'MED-1560': 1,
#   'MED-3557': 1,
#   'MED-3242': 1,
#   'MED-1563': 1,
#   'MED-1564': 1,
#   'MED-1565': 1,
#   'MED-3699': 1,
#   'MED-1567': 1,
#   'MED-1598': 1,
#   'MED-1599': 1,
#   'MED-1600': 1,
#   'MED-1601': 1,
#   'MED-1602': 1,
#   'MED-1603': 1,
#   'MED-1604': 1,
#   'MED-1605': 1,
#   'MED-1606': 1,
#   'MED-1607': 1,
#   'MED-4476': 1,
#   'MED-3841': 1,
#   'MED-3843': 1,
#   'MED-3849': 1,
#   'MED-3830': 1,
#   'MED-1825': 1,
#   'MED-1826': 1,
#   'MED-1827': 1,
#   'MED-1828': 1,
#   'MED-1829': 1,
#   'MED-1830': 1,
#   'MED-2150': 1,
#   'MED-4646': 1,
#   'MED-2152': 1,
#   'MED-2153': 1,
#   'MED-2568': 1,
#   'MED-4319': 1,
#   'MED-2570': 1,
#   'MED-2571': 1,
#   'MED-2572': 1,
#   'MED-2573': 1,
#   'MED-2574': 1,
#   'MED-2575': 1,
#   'MED-2988': 1,
#   'MED-2559': 1,
#   'MED-2577': 1,
#   'MED-2578': 1,
#   'MED-2579': 1,
#   'MED-2580': 1,
#   'MED-2581': 1,
#   'MED-2583': 1,
#   'MED-2584': 1,
#   'MED-2585': 1,
#   'MED-3270': 1,
#   'MED-3271': 1,
#   'MED-3272': 1,
#   'MED-3273': 1,
#   'MED-3274': 1,
#   'MED-3275': 1,
#   'MED-3276': 1,
#   'MED-3277': 1,
#   'MED-3278': 1,
#   'MED-3279': 1,
#   'MED-3280': 1,
#   'MED-3281': 1,
#   'MED-3282': 1,
#   'MED-3283': 1,
#   'MED-5341': 1,
#   'MED-5337': 1},
#  {'MED-4994': 2,
#   'MED-3696': 1,
#   'MED-3697': 1,
#   'MED-3698': 1,
#   'MED-3699': 1,
#   'MED-3700': 1,
#   'MED-3701': 1,
#   'MED-3762': 1,
#   'MED-3763': 1,
#   'MED-3764': 1,
#   'MED-3765': 1,
#   'MED-3766': 1,
#   'MED-3767': 1,
#   'MED-3768': 1},
#  {'MED-5012': 2, 'MED-5013': 2, 'MED-5014': 2},
#  {'MED-5026': 2,
#   'MED-5027': 2,
#   'MED-2896': 1,
#   'MED-4384': 1,
#   'MED-2898': 1,
#   'MED-2899': 1,
#   'MED-2900': 1,
#   'MED-2901': 1,
#   'MED-3422': 1,
#   'MED-3423': 1,
#   'MED-3424': 1,
#   'MED-3425': 1,
#   'MED-3426': 1,
#   'MED-3427': 1,
#   'MED-3428': 1,
#   'MED-3407': 1,
#   'MED-3429': 1,
#   'MED-3430': 1,
#   'MED-3432': 1,
#   'MED-3433': 1,
#   'MED-3434': 1,
#   'MED-3435': 1,
#   'MED-3436': 1,
#   'MED-3437': 1,
#   'MED-3438': 1,
#   'MED-3417': 1,
#   'MED-3439': 1,
#   'MED-3440': 1,
#   'MED-3420': 1,
#   'MED-3421': 1,
#   'MED-3540': 1,
#   'MED-3541': 1,
#   'MED-3542': 1,
#   'MED-3543': 1,
#   'MED-3544': 1,
#   'MED-3545': 1,
#   'MED-3546': 1,
#   'MED-3547': 1,
#   'MED-4095': 1},
#  {'MED-5041': 2,
#   'MED-5042': 2,
#   'MED-2222': 1,
#   'MED-2223': 1,
#   'MED-2224': 1,
#   'MED-2225': 1,
#   'MED-2226': 1,
#   'MED-2227': 1,
#   'MED-2228': 1,
#   'MED-4286': 1,
#   'MED-4281': 1},
#  {'MED-5056': 2,
#   'MED-3742': 1,
#   'MED-2826': 1,
#   'MED-2827': 1,
#   'MED-2830': 1,
#   'MED-2831': 1,
#   'MED-4523': 1,
#   'MED-2966': 1,
#   'MED-2967': 1,
#   'MED-2968': 1,
#   'MED-2969': 1,
#   'MED-2970': 1,
#   'MED-2971': 1,
#   'MED-2972': 1},
#  {'MED-5062': 2,
#   'MED-5063': 2,
#   'MED-3378': 1,
#   'MED-3380': 1,
#   'MED-3382': 1,
#   'MED-2616': 1,
#   'MED-2617': 1,
#   'MED-2618': 1,
#   'MED-2619': 1,
#   'MED-2992': 1,
#   'MED-2993': 1,
#   'MED-2994': 1,
#   'MED-3379': 1,
#   'MED-3381': 1},
#  {'MED-1836': 1,
#   'MED-1837': 1,
#   'MED-1838': 1,
#   'MED-1839': 1,
#   'MED-1840': 1,
#   'MED-1841': 1,
#   'MED-1842': 1,
#   'MED-1843': 1,
#   'MED-1844': 1,
#   'MED-1845': 1,
#   'MED-1846': 1,
#   'MED-3918': 1,
#   'MED-3919': 1,
#   'MED-3920': 1,
#   'MED-3921': 1,
#   'MED-3922': 1,
#   'MED-3923': 1,
#   'MED-3924': 1,
#   'MED-4049': 1,
#   'MED-4050': 1,
#   'MED-4051': 1,
#   'MED-4055': 1,
#   'MED-4332': 1},
#  {'MED-4544': 1,
#   'MED-2008': 1,
#   'MED-2009': 1,
#   'MED-2010': 1,
#   'MED-2011': 1,
#   'MED-2830': 1,
#   'MED-2831': 1,
#   'MED-3742': 1,
#   'MED-3743': 1,
#   'MED-3744': 1,
#   'MED-3745': 1,
#   'MED-3746': 1,
#   'MED-3747': 1,
#   'MED-3748': 1},
#  {'MED-5108': 2,
#   'MED-5109': 2,
#   'MED-1703': 1,
#   'MED-1699': 1,
#   'MED-1700': 1,
#   'MED-1701': 1,
#   'MED-1702': 1,
#   'MED-1762': 1,
#   'MED-1763': 1,
#   'MED-1764': 1,
#   'MED-1765': 1,
#   'MED-1766': 1,
#   'MED-1778': 1,
#   'MED-1768': 1,
#   'MED-4951': 1,
#   'MED-1770': 1,
#   'MED-1771': 1,
#   'MED-1781': 1,
#   'MED-1773': 1,
#   'MED-1774': 1,
#   'MED-3226': 1,
#   'MED-3227': 1,
#   'MED-3228': 1,
#   'MED-3229': 1,
#   'MED-3230': 1,
#   'MED-3231': 1,
#   'MED-3232': 1,
#   'MED-3233': 1,
#   'MED-4722': 1,
#   'MED-3235': 1,
#   'MED-3236': 1,
#   'MED-3237': 1,
#   'MED-3597': 1,
#   'MED-3598': 1,
#   'MED-3599': 1,
#   'MED-3780': 1,
#   'MED-3781': 1,
#   'MED-3782': 1,
#   'MED-3783': 1,
#   'MED-3784': 1,
#   'MED-3785': 1,
#   'MED-3786': 1,
#   'MED-3787': 1,
#   'MED-3788': 1,
#   'MED-3789': 1,
#   'MED-3790': 1,
#   'MED-4319': 1,
#   'MED-4320': 1,
#   'MED-4682': 1},
#  {'MED-5128': 2,
#   'MED-5129': 2,
#   'MED-5130': 2,
#   'MED-5131': 2,
#   'MED-5132': 2,
#   'MED-5133': 2,
#   'MED-5134': 2,
#   'MED-5135': 2,
#   'MED-2938': 1,
#   'MED-2939': 1,
#   'MED-2940': 1,
#   'MED-2941': 1,
#   'MED-2942': 1,
#   'MED-2943': 1,
#   'MED-2945': 1,
#   'MED-2946': 1,
#   'MED-2947': 1,
#   'MED-3985': 1,
#   'MED-3986': 1,
#   'MED-3987': 1,
#   'MED-3988': 1,
#   'MED-3989': 1,
#   'MED-3990': 1,
#   'MED-3991': 1,
#   'MED-4511': 1,
#   'MED-4512': 1,
#   'MED-4513': 1,
#   'MED-4566': 1,
#   'MED-4574': 1,
#   'MED-4575': 1,
#   'MED-4925': 1},
#  {'MED-2274': 1,
#   'MED-3535': 1,
#   'MED-2222': 1,
#   'MED-2223': 1,
#   'MED-2224': 1,
#   'MED-2225': 1,
#   'MED-2226': 1,
#   'MED-2227': 1,
#   'MED-2228': 1,
#   'MED-2279': 1,
#   'MED-2280': 1,
#   'MED-2281': 1,
#   'MED-2282': 1,
#   'MED-3464': 1,
#   'MED-2284': 1,
#   'MED-2285': 1,
#   'MED-2287': 1,
#   'MED-3518': 1,
#   'MED-3519': 1,
#   'MED-3520': 1,
#   'MED-3521': 1,
#   'MED-3522': 1,
#   'MED-3523': 1,
#   'MED-3524': 1,
#   'MED-3525': 1,
#   'MED-3526': 1,
#   'MED-3527': 1,
#   'MED-3528': 1,
#   'MED-3539': 1,
#   'MED-3530': 1,
#   'MED-3531': 1,
#   'MED-3532': 1,
#   'MED-3533': 1,
#   'MED-3534': 1,
#   'MED-3906': 1,
#   'MED-3907': 1,
#   'MED-3908': 1,
#   'MED-4715': 1,
#   'MED-3910': 1,
#   'MED-4106': 1,
#   'MED-4286': 1,
#   'MED-4281': 1},
#  {'MED-5159': 2,
#   'MED-5160': 2,
#   'MED-5161': 2,
#   'MED-5162': 2,
#   'MED-4390': 1,
#   'MED-1880': 1,
#   'MED-1881': 1,
#   'MED-2098': 1,
#   'MED-3548': 1,
#   'MED-3549': 1,
#   'MED-3550': 1,
#   'MED-3551': 1,
#   'MED-3552': 1,
#   'MED-3553': 1,
#   'MED-3554': 1,
#   'MED-3555': 1,
#   'MED-4049': 1,
#   'MED-4053': 1,
#   'MED-4051': 1,
#   'MED-5116': 1,
#   'MED-4047': 1,
#   'MED-4055': 1,
#   'MED-4286': 1,
#   'MED-4281': 1,
#   'MED-4585': 1,
#   'MED-4590': 1,
#   'MED-4587': 1,
#   'MED-4588': 1,
#   'MED-4589': 1},
#  {'MED-5177': 2,
#   'MED-5175': 2,
#   'MED-2099': 1,
#   'MED-2100': 1,
#   'MED-2101': 1,
#   'MED-2102': 1,
#   'MED-2103': 1,
#   'MED-2529': 1,
#   'MED-2105': 1,
#   'MED-2106': 1,
#   'MED-2107': 1,
#   'MED-2108': 1,
#   'MED-4637': 1,
#   'MED-4638': 1,
#   'MED-4639': 1,
#   'MED-4640': 1,
#   'MED-4641': 1},
#  {'MED-5260': 2,
#   'MED-5261': 2,
#   'MED-5262': 2,
#   'MED-5263': 2,
#   'MED-5278': 2,
#   'MED-5265': 2,
#   'MED-5266': 2,
#   'MED-5267': 2,
#   'MED-5268': 2,
#   'MED-5269': 2,
#   'MED-5270': 2,
#   'MED-5271': 2,
#   'MED-5272': 2,
#   'MED-5273': 2,
#   'MED-5274': 2,
#   'MED-1401': 1,
#   'MED-1402': 1,
#   'MED-1366': 1,
#   'MED-1403': 1,
#   'MED-1404': 1,
#   'MED-1405': 1,
#   'MED-1406': 1,
#   'MED-1407': 1,
#   'MED-1408': 1,
#   'MED-1409': 1,
#   'MED-1410': 1,
#   'MED-1411': 1,
#   'MED-1634': 1,
#   'MED-1635': 1,
#   'MED-1636': 1,
#   'MED-1637': 1,
#   'MED-1638': 1,
#   'MED-1639': 1,
#   'MED-1640': 1,
#   'MED-1641': 1,
#   'MED-1642': 1,
#   'MED-1643': 1,
#   'MED-5258': 1,
#   'MED-1645': 1,
#   'MED-1646': 1,
#   'MED-1647': 1,
#   'MED-1648': 1,
#   'MED-1649': 1,
#   'MED-2222': 1,
#   'MED-2223': 1,
#   'MED-2224': 1,
#   'MED-2225': 1,
#   'MED-2226': 1,
#   'MED-2227': 1,
#   'MED-2228': 1,
#   'MED-2370': 1,
#   'MED-2371': 1,
#   'MED-2372': 1,
#   'MED-4324': 1,
#   'MED-2376': 1,
#   'MED-2593': 1,
#   'MED-2378': 1,
#   'MED-2379': 1,
#   'MED-2380': 1,
#   'MED-2381': 1,
#   'MED-2382': 1,
#   'MED-2383': 1,
#   'MED-2384': 1,
#   'MED-4249': 1},
#  {'MED-5343': 2,
#   'MED-5344': 2,
#   'MED-5345': 2,
#   'MED-5346': 2,
#   'MED-5347': 2,
#   'MED-1487': 1,
#   'MED-1482': 1,
#   'MED-1483': 1,
#   'MED-1484': 1,
#   'MED-1490': 1,
#   'MED-3113': 1,
#   'MED-4247': 1,
#   'MED-3623': 1,
#   'MED-3624': 1,
#   'MED-3625': 1,
#   'MED-3626': 1,
#   'MED-3627': 1}]

# %%
qrels_df = pd.DataFrame({
    'query_id': list(qrels.keys()),
    'relevant_docs': [list(rel_docs.keys()) for rel_docs in list(qrels.values())]
})

# %%
retrieval_df = pd.read_csv(os.path.join(data_path, 'cosine', "retrieval_results.csv"))
retrieval_df.head()
# Out:
#    query_id                                              query  \
# 0   PLAIN-2   Do Cholesterol Statin Drugs Cause Breast Cancer?
# 1  PLAIN-12                Exploiting Autophagy to Live Longer
# 2  PLAIN-23  How to Reduce Exposure to Alkylphenols Through...
# 3  PLAIN-33          What’s Driving America’s Obesity Problem?
# 4  PLAIN-44              Who Should be Careful About Curcumin?
#
#                                 retrieved_docs_top50  \
# 0  ['MED-2429', 'MED-14', 'MED-2431', 'MED-10', '...
# 1  ['MED-2514', 'MED-1437', 'MED-1432', 'MED-1436...
# 2  ['MED-4726', 'MED-999', 'MED-1004', 'MED-1961'...
# 3  ['MED-2721', 'MED-2721', 'MED-2722', 'MED-2723...
# 4  ['MED-2824', 'MED-1110', 'MED-1811', 'MED-2794...
#
#                                retrieved_texts_top50  \
# 0  ["Emerging evidence suggests that statins' may...
# 1  ["Healthy life span is rapidly increasing and ...
# 2  ["The aim of these studies was to evaluate the...
# 3  ['BACKGROUND: The major drivers of the obesity...
# 4  ['Cancer is primarily a disease of old age, an...
#
#                                  retrieved_sim_top50
# 0  [0.9891527891159058, 0.9874821901321411, 0.986...
# 1  [0.9835842847824097, 0.9829482436180115, 0.981...
# 2  [0.9849041700363159, 0.9845057129859924, 0.983...
# 3  [0.9824672937393188, 0.9813079833984375, 0.981...
# 4  [0.979678750038147, 0.9796613454818726, 0.9795...

# %%
DOCS_IN_CORPUS = list(corpus_df.index)
DOCS_IN_CORPUS
# Out:
# ['MED-10',
#  'MED-14',
#  'MED-118',
#  'MED-301',
#  'MED-306',
#  'MED-329',
#  'MED-330',
#  'MED-332',
#  'MED-334',
#  'MED-335',
#  'MED-398',
#  'MED-557',
#  'MED-666',
#  'MED-691',
#  'MED-692',
#  'MED-702',
#  'MED-706',
#  'MED-707',
#  'MED-708',
#  'MED-709',
#  'MED-711',
#  'MED-712',
#  'MED-713',
#  'MED-714',
#  'MED-716',
#  'MED-717',
#  'MED-718',
#  'MED-719',
#  'MED-720',
#  'MED-721',
#  'MED-722',
#  'MED-723',
#  'MED-724',
#  'MED-726',
#  'MED-727',
#  'MED-728',
#  'MED-729',
#  'MED-730',
#  'MED-731',
#  'MED-732',
#  'MED-733',
#  'MED-734',
#  'MED-735',
#  'MED-736',
#  'MED-743',
#  'MED-744',
#  'MED-745',
#  'MED-746',
#  'MED-748',
#  'MED-749',
#  'MED-751',
#  'MED-752',
#  'MED-753',
#  'MED-754',
#  'MED-756',
#  'MED-757',
#  'MED-758',
#  'MED-759',
#  'MED-760',
#  'MED-761',
#  'MED-762',
#  'MED-816',
#  'MED-818',
#  'MED-819',
#  'MED-820',
#  'MED-821',
#  'MED-822',
#  'MED-823',
#  'MED-824',
#  'MED-825',
#  'MED-826',
#  'MED-827',
#  'MED-828',
#  'MED-829',
#  'MED-830',
#  'MED-831',
#  'MED-832',
#  'MED-833',
#  'MED-834',
#  'MED-835',
#  'MED-836',
#  'MED-837',
#  'MED-838',
#  'MED-839',
#  'MED-840',
#  'MED-841',
#  'MED-842',
#  'MED-843',
#  'MED-844',
#  'MED-845',
#  'MED-846',
#  'MED-850',
#  'MED-851',
#  'MED-852',
#  'MED-853',
#  'MED-854',
#  'MED-855',
#  'MED-857',
#  'MED-859',
#  'MED-860',
#  'MED-861',
#  'MED-862',
#  'MED-863',
#  'MED-864',
#  'MED-865',
#  'MED-866',
#  'MED-867',
#  'MED-868',
#  'MED-869',
#  'MED-870',
#  'MED-872',
#  'MED-876',
#  'MED-877',
#  'MED-878',
#  'MED-880',
#  'MED-884',
#  'MED-885',
#  'MED-886',
#  'MED-887',
#  'MED-888',
#  'MED-890',
#  'MED-891',
#  'MED-894',
#  'MED-895',
#  'MED-897',
#  'MED-898',
#  'MED-899',
#  'MED-900',
#  'MED-901',
#  'MED-902',
#  'MED-903',
#  'MED-904',
#  'MED-907',
#  'MED-909',
#  'MED-910',
#  'MED-911',
#  'MED-912',
#  'MED-913',
#  'MED-918',
#  'MED-919',
#  'MED-920',
#  'MED-921',
#  'MED-922',
#  'MED-923',
#  'MED-927',
#  'MED-928',
#  'MED-930',
#  'MED-931',
#  'MED-933',
#  'MED-934',
#  'MED-936',
#  'MED-943',
#  'MED-944',
#  'MED-945',
#  'MED-946',
#  'MED-947',
#  'MED-948',
#  'MED-949',
#  'MED-950',
#  'MED-951',
#  'MED-953',
#  'MED-954',
#  'MED-955',
#  'MED-956',
#  'MED-957',
#  'MED-958',
#  'MED-959',
#  'MED-960',
#  'MED-962',
#  'MED-963',
#  'MED-965',
#  'MED-966',
#  'MED-967',
#  'MED-969',
#  'MED-970',
#  'MED-972',
#  'MED-973',
#  'MED-974',
#  'MED-975',
#  'MED-976',
#  'MED-977',
#  'MED-978',
#  'MED-979',
#  'MED-980',
#  'MED-981',
#  'MED-982',
#  'MED-983',
#  'MED-984',
#  'MED-985',
#  'MED-986',
#  'MED-987',
#  'MED-988',
#  'MED-990',
#  'MED-991',
#  'MED-992',
#  'MED-993',
#  'MED-994',
#  'MED-995',
#  'MED-996',
#  'MED-998',
#  'MED-999',
#  'MED-1000',
#  'MED-1002',
#  'MED-1003',
#  'MED-1004',
#  'MED-1005',
#  'MED-1006',
#  'MED-1007',
#  'MED-1008',
#  'MED-1009',
#  'MED-1010',
#  'MED-1011',
#  'MED-1012',
#  'MED-1013',
#  'MED-1014',
#  'MED-1015',
#  'MED-1016',
#  'MED-1017',
#  'MED-1018',
#  'MED-1019',
#  'MED-1020',
#  'MED-1021',
#  'MED-1023',
#  'MED-1025',
#  'MED-1026',
#  'MED-1027',
#  'MED-1028',
#  'MED-1029',
#  'MED-1030',
#  'MED-1031',
#  'MED-1032',
#  'MED-1033',
#  'MED-1034',
#  'MED-1035',
#  'MED-1036',
#  'MED-1037',
#  'MED-1038',
#  'MED-1039',
#  'MED-1040',
#  'MED-1041',
#  'MED-1042',
#  'MED-1045',
#  'MED-1046',
#  'MED-1047',
#  'MED-1048',
#  'MED-1049',
#  'MED-1050',
#  'MED-1051',
#  'MED-1053',
#  'MED-1054',
#  'MED-1055',
#  'MED-1056',
#  'MED-1058',
#  'MED-1060',
#  'MED-1061',
#  'MED-1062',
#  'MED-1063',
#  'MED-1066',
#  'MED-1067',
#  'MED-1068',
#  'MED-1069',
#  'MED-1070',
#  'MED-1071',
#  'MED-1072',
#  'MED-1097',
#  'MED-1098',
#  'MED-1099',
#  'MED-1100',
#  'MED-1101',
#  'MED-1103',
#  'MED-1104',
#  'MED-1105',
#  'MED-1106',
#  'MED-1107',
#  'MED-1108',
#  'MED-1109',
#  'MED-1110',
#  'MED-1111',
#  'MED-1112',
#  'MED-1113',
#  'MED-1114',
#  'MED-1115',
#  'MED-1116',
#  'MED-1118',
#  'MED-1120',
#  'MED-1121',
#  'MED-1122',
#  'MED-1123',
#  'MED-1124',
#  'MED-1125',
#  'MED-1126',
#  'MED-1127',
#  'MED-1128',
#  'MED-1129',
#  'MED-1130',
#  'MED-1131',
#  'MED-1133',
#  'MED-1134',
#  'MED-1135',
#  'MED-1136',
#  'MED-1137',
#  'MED-1138',
#  'MED-1139',
#  'MED-1140',
#  'MED-1142',
#  'MED-1143',
#  'MED-1144',
#  'MED-1146',
#  'MED-1147',
#  'MED-1148',
#  'MED-1149',
#  'MED-1150',
#  'MED-1151',
#  'MED-1152',
#  'MED-1153',
#  'MED-1156',
#  'MED-1157',
#  'MED-1158',
#  'MED-1160',
#  'MED-1161',
#  'MED-1162',
#  'MED-1164',
#  'MED-1165',
#  'MED-1166',
#  'MED-1167',
#  'MED-1169',
#  'MED-1170',
#  'MED-1171',
#  'MED-1172',
#  'MED-1173',
#  'MED-1174',
#  'MED-1175',
#  'MED-1176',
#  'MED-1177',
#  'MED-1178',
#  'MED-1179',
#  'MED-1180',
#  'MED-1181',
#  'MED-1182',
#  'MED-1184',
#  'MED-1185',
#  'MED-1186',
#  'MED-1187',
#  'MED-1188',
#  'MED-1190',
#  'MED-1192',
#  'MED-1193',
#  'MED-1194',
#  'MED-1195',
#  'MED-1196',
#  'MED-1198',
#  'MED-1199',
#  'MED-1200',
#  'MED-1201',
#  'MED-1202',
#  'MED-1203',
#  'MED-1204',
#  'MED-1205',
#  'MED-1207',
#  'MED-1208',
#  'MED-1209',
#  'MED-1210',
#  'MED-1211',
#  'MED-1212',
#  'MED-1213',
#  'MED-1215',
#  'MED-1216',
#  'MED-1217',
#  'MED-1218',
#  'MED-1219',
#  'MED-1220',
#  'MED-1221',
#  'MED-1223',
#  'MED-1224',
#  'MED-1226',
#  'MED-1227',
#  'MED-1229',
#  'MED-1230',
#  'MED-1231',
#  'MED-1232',
#  'MED-1233',
#  'MED-1234',
#  'MED-1236',
#  'MED-1237',
#  'MED-1238',
#  'MED-1240',
#  'MED-1241',
#  'MED-1242',
#  'MED-1243',
#  'MED-1244',
#  'MED-1245',
#  'MED-1246',
#  'MED-1247',
#  'MED-1248',
#  'MED-1249',
#  'MED-1250',
#  'MED-1252',
#  'MED-1253',
#  'MED-1254',
#  'MED-1256',
#  'MED-1257',
#  'MED-1258',
#  'MED-1259',
#  'MED-1261',
#  'MED-1262',
#  'MED-1265',
#  'MED-1266',
#  'MED-1267',
#  'MED-1268',
#  'MED-1271',
#  'MED-1272',
#  'MED-1273',
#  'MED-1274',
#  'MED-1276',
#  'MED-1277',
#  'MED-1278',
#  'MED-1279',
#  'MED-1280',
#  'MED-1281',
#  'MED-1282',
#  'MED-1283',
#  'MED-1284',
#  'MED-1285',
#  'MED-1287',
#  'MED-1288',
#  'MED-1289',
#  'MED-1290',
#  'MED-1291',
#  'MED-1292',
#  'MED-1293',
#  'MED-1294',
#  'MED-1295',
#  'MED-1296',
#  'MED-1298',
#  'MED-1299',
#  'MED-1300',
#  'MED-1301',
#  'MED-1302',
#  'MED-1303',
#  'MED-1304',
#  'MED-1305',
#  'MED-1307',
#  'MED-1308',
#  'MED-1309',
#  'MED-1311',
#  'MED-1312',
#  'MED-1313',
#  'MED-1314',
#  'MED-1315',
#  'MED-1316',
#  'MED-1317',
#  'MED-1318',
#  'MED-1319',
#  'MED-1320',
#  'MED-1321',
#  'MED-1322',
#  'MED-1323',
#  'MED-1324',
#  'MED-1326',
#  'MED-1327',
#  'MED-1328',
#  'MED-1329',
#  'MED-1330',
#  'MED-1331',
#  'MED-1332',
#  'MED-1333',
#  'MED-1334',
#  'MED-1335',
#  'MED-1337',
#  'MED-1338',
#  'MED-1339',
#  'MED-1340',
#  'MED-1341',
#  'MED-1342',
#  'MED-1343',
#  'MED-1344',
#  'MED-1345',
#  'MED-1347',
#  'MED-1348',
#  'MED-1349',
#  'MED-1350',
#  'MED-1351',
#  'MED-1352',
#  'MED-1353',
#  'MED-1354',
#  'MED-1355',
#  'MED-1356',
#  'MED-1357',
#  'MED-1358',
#  'MED-1359',
#  'MED-1360',
#  'MED-1362',
#  'MED-1363',
#  'MED-1365',
#  'MED-1366',
#  'MED-1371',
#  'MED-1373',
#  'MED-1374',
#  'MED-1375',
#  'MED-1376',
#  'MED-1377',
#  'MED-1378',
#  'MED-1380',
#  'MED-1381',
#  'MED-1383',
#  'MED-1386',
#  'MED-1387',
#  'MED-1388',
#  'MED-1389',
#  'MED-1390',
#  'MED-1393',
#  'MED-1394',
#  'MED-1395',
#  'MED-1397',
#  'MED-1398',
#  'MED-1399',
#  'MED-1400',
#  'MED-1401',
#  'MED-1402',
#  'MED-1403',
#  'MED-1404',
#  'MED-1405',
#  'MED-1406',
#  'MED-1407',
#  'MED-1408',
#  'MED-1409',
#  'MED-1410',
#  'MED-1411',
#  'MED-1412',
#  'MED-1413',
#  'MED-1414',
#  'MED-1415',
#  'MED-1416',
#  'MED-1417',
#  'MED-1418',
#  'MED-1419',
#  'MED-1420',
#  'MED-1421',
#  'MED-1425',
#  'MED-1426',
#  'MED-1428',
#  'MED-1429',
#  'MED-1430',
#  'MED-1431',
#  'MED-1432',
#  'MED-1433',
#  'MED-1434',
#  'MED-1435',
#  'MED-1436',
#  'MED-1437',
#  'MED-1438',
#  'MED-1439',
#  'MED-1440',
#  'MED-1441',
#  'MED-1442',
#  'MED-1443',
#  'MED-1444',
#  'MED-1445',
#  'MED-1446',
#  'MED-1447',
#  'MED-1448',
#  'MED-1449',
#  'MED-1450',
#  'MED-1451',
#  'MED-1454',
#  'MED-1455',
#  'MED-1456',
#  'MED-1457',
#  'MED-1458',
#  'MED-1459',
#  'MED-1460',
#  'MED-1461',
#  'MED-1463',
#  'MED-1464',
#  'MED-1465',
#  'MED-1466',
#  'MED-1467',
#  'MED-1468',
#  'MED-1470',
#  'MED-1471',
#  'MED-1472',
#  'MED-1473',
#  'MED-1474',
#  'MED-1475',
#  'MED-1476',
#  'MED-1478',
#  'MED-1479',
#  'MED-1482',
#  'MED-1483',
#  'MED-1484',
#  'MED-1486',
#  'MED-1487',
#  'MED-1488',
#  'MED-1489',
#  'MED-1490',
#  'MED-1491',
#  'MED-1492',
#  'MED-1493',
#  'MED-1494',
#  'MED-1495',
#  'MED-1496',
#  'MED-1497',
#  'MED-1498',
#  'MED-1499',
#  'MED-1500',
#  'MED-1501',
#  'MED-1502',
#  'MED-1503',
#  'MED-1504',
#  'MED-1505',
#  'MED-1506',
#  'MED-1507',
#  'MED-1508',
#  'MED-1509',
#  'MED-1510',
#  'MED-1511',
#  'MED-1512',
#  'MED-1513',
#  'MED-1514',
#  'MED-1515',
#  'MED-1516',
#  'MED-1517',
#  'MED-1518',
#  'MED-1519',
#  'MED-1520',
#  'MED-1521',
#  'MED-1522',
#  'MED-1523',
#  'MED-1524',
#  'MED-1525',
#  'MED-1526',
#  'MED-1527',
#  'MED-1528',
#  'MED-1529',
#  'MED-1530',
#  'MED-1531',
#  'MED-1532',
#  'MED-1533',
#  'MED-1534',
#  'MED-1535',
#  'MED-1538',
#  'MED-1540',
#  'MED-1541',
#  'MED-1542',
#  'MED-1543',
#  'MED-1544',
#  'MED-1545',
#  'MED-1546',
#  'MED-1548',
#  'MED-1549',
#  'MED-1551',
#  'MED-1552',
#  'MED-1553',
#  'MED-1554',
#  'MED-1555',
#  'MED-1556',
#  'MED-1557',
#  'MED-1558',
#  'MED-1559',
#  'MED-1560',
#  'MED-1563',
#  'MED-1564',
#  'MED-1565',
#  'MED-1567',
#  'MED-1568',
#  'MED-1569',
#  'MED-1570',
#  'MED-1571',
#  'MED-1572',
#  'MED-1573',
#  'MED-1574',
#  'MED-1575',
#  'MED-1576',
#  'MED-1577',
#  'MED-1578',
#  'MED-1579',
#  'MED-1580',
#  'MED-1581',
#  'MED-1582',
#  'MED-1584',
#  'MED-1585',
#  'MED-1586',
#  'MED-1587',
#  'MED-1588',
#  'MED-1592',
#  'MED-1593',
#  'MED-1594',
#  'MED-1595',
#  'MED-1596',
#  'MED-1597',
#  'MED-1598',
#  'MED-1599',
#  'MED-1600',
#  'MED-1601',
#  'MED-1602',
#  'MED-1603',
#  'MED-1604',
#  'MED-1605',
#  'MED-1606',
#  'MED-1607',
#  'MED-1609',
#  'MED-1610',
#  'MED-1611',
#  'MED-1612',
#  'MED-1613',
#  'MED-1614',
#  'MED-1615',
#  'MED-1616',
#  'MED-1617',
#  'MED-1618',
#  'MED-1619',
#  'MED-1620',
#  'MED-1621',
#  'MED-1622',
#  'MED-1623',
#  'MED-1624',
#  'MED-1625',
#  'MED-1626',
#  'MED-1627',
#  'MED-1628',
#  'MED-1630',
#  'MED-1631',
#  'MED-1634',
#  'MED-1635',
#  'MED-1636',
#  'MED-1637',
#  'MED-1638',
#  'MED-1639',
#  'MED-1640',
#  'MED-1641',
#  'MED-1642',
#  'MED-1643',
#  'MED-1645',
#  'MED-1646',
#  'MED-1647',
#  'MED-1648',
#  'MED-1649',
#  'MED-1650',
#  'MED-1651',
#  'MED-1655',
#  'MED-1656',
#  'MED-1657',
#  'MED-1658',
#  'MED-1659',
#  'MED-1660',
#  'MED-1661',
#  'MED-1663',
#  'MED-1664',
#  'MED-1665',
#  'MED-1666',
#  'MED-1667',
#  'MED-1668',
#  'MED-1669',
#  'MED-1670',
#  'MED-1671',
#  'MED-1672',
#  'MED-1673',
#  'MED-1674',
#  'MED-1675',
#  'MED-1676',
#  'MED-1677',
#  'MED-1678',
#  'MED-1679',
#  'MED-1680',
#  'MED-1681',
#  'MED-1682',
#  'MED-1683',
#  'MED-1685',
#  'MED-1686',
#  'MED-1687',
#  'MED-1688',
#  'MED-1689',
#  'MED-1690',
#  'MED-1691',
#  'MED-1693',
#  'MED-1695',
#  'MED-1696',
#  'MED-1697',
#  'MED-1699',
#  'MED-1700',
#  'MED-1701',
#  'MED-1702',
#  'MED-1703',
#  'MED-1704',
#  'MED-1705',
#  'MED-1706',
#  'MED-1707',
#  'MED-1708',
#  'MED-1709',
#  'MED-1710',
#  'MED-1711',
#  'MED-1712',
#  'MED-1714',
#  'MED-1715',
#  'MED-1716',
#  'MED-1717',
#  'MED-1718',
#  'MED-1719',
#  'MED-1720',
#  'MED-1721',
#  'MED-1722',
#  'MED-1723',
#  'MED-1724',
#  'MED-1725',
#  'MED-1726',
#  'MED-1728',
#  'MED-1729',
#  'MED-1730',
#  'MED-1731',
#  'MED-1732',
#  'MED-1733',
#  'MED-1736',
#  'MED-1737',
#  'MED-1738',
#  'MED-1739',
#  'MED-1740',
#  'MED-1741',
#  'MED-1743',
#  'MED-1744',
#  'MED-1745',
#  'MED-1746',
#  'MED-1747',
#  'MED-1748',
#  'MED-1749',
#  'MED-1750',
#  'MED-1751',
#  'MED-1752',
#  'MED-1753',
#  'MED-1754',
#  'MED-1755',
#  'MED-1757',
#  'MED-1759',
#  'MED-1760',
#  'MED-1761',
#  'MED-1762',
#  'MED-1763',
#  'MED-1764',
#  'MED-1765',
#  'MED-1766',
#  'MED-1768',
#  'MED-1770',
#  'MED-1771',
#  'MED-1773',
#  'MED-1774',
#  'MED-1775',
#  'MED-1776',
#  'MED-1777',
#  'MED-1778',
#  'MED-1779',
#  'MED-1780',
#  'MED-1781',
#  'MED-1782',
#  'MED-1783',
#  'MED-1784',
#  'MED-1785',
#  'MED-1786',
#  'MED-1787',
#  'MED-1788',
#  'MED-1789',
#  'MED-1790',
#  'MED-1791',
#  'MED-1792',
#  'MED-1793',
#  'MED-1794',
#  'MED-1795',
#  'MED-1796',
#  'MED-1797',
#  'MED-1798',
#  'MED-1799',
#  'MED-1800',
#  'MED-1801',
#  'MED-1802',
#  'MED-1803',
#  'MED-1804',
#  'MED-1806',
#  'MED-1807',
#  'MED-1808',
#  'MED-1810',
#  'MED-1811',
#  'MED-1812',
#  'MED-1813',
#  'MED-1814',
#  'MED-1817',
#  'MED-1818',
#  'MED-1819',
#  'MED-1820',
#  'MED-1825',
#  'MED-1826',
#  'MED-1827',
#  'MED-1828',
#  'MED-1829',
#  'MED-1830',
#  'MED-1831',
#  'MED-1832',
#  'MED-1833',
#  'MED-1834',
#  'MED-1836',
#  'MED-1837',
#  'MED-1838',
#  'MED-1839',
#  'MED-1840',
#  'MED-1841',
#  'MED-1842',
#  'MED-1843',
#  'MED-1844',
#  'MED-1845',
#  'MED-1846',
#  'MED-1847',
#  'MED-1848',
#  'MED-1849',
#  'MED-1850',
#  'MED-1851',
#  'MED-1852',
#  'MED-1853',
#  'MED-1857',
#  'MED-1858',
#  'MED-1859',
#  'MED-1860',
#  'MED-1861',
#  'MED-1862',
#  'MED-1863',
#  'MED-1864',
#  'MED-1865',
#  'MED-1866',
#  'MED-1867',
#  'MED-1868',
#  'MED-1869',
#  'MED-1871',
#  'MED-1872',
#  'MED-1873',
#  'MED-1874',
#  'MED-1876',
#  'MED-1878',
#  'MED-1879',
#  'MED-1880',
#  'MED-1881',
#  'MED-1882',
#  'MED-1884',
#  'MED-1885',
#  'MED-1886',
#  'MED-1887',
#  'MED-1888',
#  'MED-1889',
#  'MED-1890',
#  'MED-1914',
#  'MED-1915',
#  'MED-1916',
#  'MED-1917',
#  'MED-1918',
#  'MED-1919',
#  'MED-1920',
#  'MED-1921',
#  'MED-1922',
#  'MED-1923',
#  'MED-1924',
#  'MED-1926',
#  'MED-1928',
#  'MED-1929',
#  'MED-1930',
#  'MED-1931',
#  'MED-1932',
#  'MED-1933',
#  'MED-1934',
#  'MED-1935',
#  'MED-1936',
#  'MED-1937',
#  'MED-1939',
#  'MED-1941',
#  'MED-1942',
#  'MED-1944',
#  'MED-1947',
#  'MED-1948',
#  'MED-1949',
#  'MED-1950',
#  'MED-1951',
#  'MED-1952',
#  'MED-1953',
#  'MED-1954',
#  'MED-1955',
#  'MED-1956',
#  'MED-1957',
#  'MED-1958',
#  'MED-1959',
#  'MED-1960',
#  'MED-1961',
#  'MED-1962',
#  'MED-1963',
#  'MED-1966',
#  'MED-1968',
#  'MED-1977',
#  'MED-1978',
#  'MED-1979',
#  'MED-1980',
#  'MED-1981',
#  'MED-1982',
#  'MED-1983',
#  'MED-1985',
#  'MED-1986',
#  'MED-1987',
#  'MED-1988',
#  ...]

# %%
corpus_df.to_csv(os.path.join(data_path, "corpus.csv"), index=False)
queries_df.to_csv(os.path.join(data_path, "queries.csv"), index=False)
qrels_df.to_csv(os.path.join(data_path, "qrels.csv"), index=False)

# %%
from sklearn.metrics import precision_score, recall_score


def compute_accuracy(retrieved_docs, relevant_docs, top_k=10):
    # Handle empty retrieved_docs
    if isinstance(retrieved_docs, str):
        if retrieved_docs.strip() == "":
            return 0, 0, 0, 0
        retrieved_docs = retrieved_docs[1:-1].replace("'", "").split(", ")
    retrieved_docs = retrieved_docs[:top_k]
    
    # Handle empty relevant_docs
    if isinstance(relevant_docs, str):
        if relevant_docs.strip() == "":
            return 0, 0, 0, 0
        relevant_docs = relevant_docs[1:-1].replace("'", "").split(", ")
    relevant_docs = relevant_docs[:top_k]
    
    retrieved_docs_set = set(retrieved_docs)
    relevant_docs_set = set(relevant_docs)
    
    logging.info(f"Retrieved documents: {retrieved_docs}")
    logging.info(f"Relevant documents: {relevant_docs}")
    
    common_docs_set = retrieved_docs_set.intersection(relevant_docs_set)
    logging.info(f"Common documents: {common_docs_set}")
    
    # Calculate intersect accuracy
    intersect_accuracy = len(common_docs_set) / len(relevant_docs_set) if relevant_docs_set else 0
    
    # Calculate precision and recall
    precision = len(common_docs_set) / len(retrieved_docs_set) if retrieved_docs_set else 0
    recall = len(common_docs_set) / len(relevant_docs_set) if relevant_docs_set else 0
    logging.info(f"Length of retrieved docs: {len(retrieved_docs_set)}")
    logging.info(f"Length of relevant docs: {len(relevant_docs_set)}")
    logging.info(f"Length of common docs: {len(common_docs_set)}")
    
    return intersect_accuracy, precision, recall


# # Example usage
# retrieved_docs = "['doc1', 'doc2', 'doc3']"
# relevant_docs = "['doc2', 'doc3', 'doc4']"
# DOCS_IN_CORPUS = ['doc1', 'doc2', 'doc3', 'doc4', 'doc5']

# intersect_accuracy, precision_inner, precision_ohe, recall_ohe = compute_accuracy(retrieved_docs, relevant_docs)
# print(intersect_accuracy, precision_inner, precision_ohe, recall_ohe)

# %%
retrieval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   query_id               323 non-null    object
#  1   query                  323 non-null    object
#  2   retrieved_docs_top50   323 non-null    object
#  3   retrieved_texts_top50  323 non-null    object
#  4   retrieved_sim_top50    323 non-null    object
#  5   relevant_docs          323 non-null    object
# dtypes: object(6)
# memory usage: 15.3+ KB

# %%
METHODS_LIST = ["cosine", "hybrid", "cross_encoder_rerank", "keyword_rerank"]
k_list = [1, 3, 5, 10, 20]

for item in os.listdir(data_path):
    if item in METHODS_LIST:
        retrieval_df = pd.read_csv(os.path.join(data_path, item, "retrieval_results.csv"))
        retrieval_df['query_id'] = retrieval_df['query_id'].astype(str)
        cols_to_keep = ["query_id", "query", "retrieved_docs_top50", "retrieved_texts_top50", "retrieved_sim_top50"]
        retrieval_df = retrieval_df[cols_to_keep]
        retrieval_df = retrieval_df.merge(qrels_df, on=["query_id"], how="inner")
        print(retrieval_df.columns)
        
        for k in k_list:
            retrieval_df[f"accuracy_top{k}"], retrieval_df[f"precision_top{k}"], retrieval_df[f"recall_top{k}"] = retrieval_df.apply(
                    lambda x: compute_accuracy(x[f"retrieved_docs_top50"], x["relevant_docs"], top_k=k),
                    axis=1, result_type="expand"
                )
        retrieval_df.to_csv(os.path.join(data_path, item, f"retrieval_results.csv"), index=False)
# Out:
# Index(['query_id', 'query', 'retrieved_docs_top50', 'retrieved_texts_top50',
#        'retrieved_sim_top50', 'relevant_docs'],
#       dtype='object')
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2429']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2427']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2514']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2513']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4726']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2644']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2721']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2717']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2824']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2780']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2900']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2896']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2991']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2991']
# 2024-05-23 21:35:38 - Common documents: {'MED-2991'}
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 1
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1421']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-332']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3169']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3178']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1366']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3254']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3380']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3378']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2707']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3474']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4116']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3549']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3619']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3618']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3679']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3679']
# 2024-05-23 21:35:38 - Common documents: {'MED-3679'}
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 1
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3696']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3762']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-825']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3815']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1028']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3904']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3969']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3960']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4057']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4053']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3243']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4103']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4504']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4544']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2391']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4474']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4890']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-5176']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4296']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4295']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4331']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4328']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3023']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4375']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2100']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4516']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-714']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-714']
# 2024-05-23 21:35:38 - Common documents: {'MED-714'}
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 1
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2437']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4650']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-760']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-759']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2405']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2394']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1399']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4324']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1124']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-861']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4469']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4203']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2783']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-892']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-906']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-906']
# 2024-05-23 21:35:38 - Common documents: {'MED-906'}
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 1
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-917']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3714']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-927']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-927']
# 2024-05-23 21:35:38 - Common documents: {'MED-927'}
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 1
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-942']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-941']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1751']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-952']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4573']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-961']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3379']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4222']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1796']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-1796']
# 2024-05-23 21:35:38 - Common documents: {'MED-1796'}
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 1
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1115']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2896']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4555']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3617']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4142']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-5155']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1017']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2527']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-872']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3618']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-991']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4380']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3180']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4422']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2346']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2337']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2762']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2575']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1030']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4399']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1041']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4413']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2664']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-1195']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4880']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2522']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1098']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-1463']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1365']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3146']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2144']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2513']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4857']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4857']
# 2024-05-23 21:35:38 - Common documents: {'MED-4857'}
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 1
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-5017']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-5017']
# 2024-05-23 21:35:38 - Common documents: {'MED-5017'}
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 1
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4909']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-1847']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-2280']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3714']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1027']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-398']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1278']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-1265']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1339']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-2988']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4236']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3874']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3135']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3136']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3800']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3796']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-3386']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-3385']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-1055']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-4991']
# 2024-05-23 21:35:38 - Common documents: set()
# 2024-05-23 21:35:38 - Length of retrieved docs: 1
# 2024-05-23 21:35:38 - Length of relevant docs: 1
# 2024-05-23 21:35:38 - Length of common docs: 0
# 2024-05-23 21:35:38 - Retrieved documents: ['MED-4546']
# 2024-05-23 21:35:38 - Relevant documents: ['MED-
#      precision_top1  recall_top1  accuracy_top3  ...  recall_top3  \
# 0                 1            2              0  ...            2
# 1                 1            2              0  ...            2
# 2                 1            2              0  ...            2
# 3                 1            2              0  ...            2
# 4                 1            2              0  ...            2
# ..              ...          ...            ...  ...          ...
# 318               1            2              0  ...            2
# 319               1            2              0  ...            2
# 320               1            2              0  ...            2
# 321               1            2              0  ...            2
# 322               1            2              0  ...            2
#
#      accuracy_top5  precision_top5  recall_top5  accuracy_top10  \
# 0                0               1            2               0
# 1                0               1            2               0
# 2                0               1            2               0
# 3                0               1            2               0
# 4                0               1            2               0
# ..             ...             ...          ...             ...
# 318              0               1            2               0
# 319              0               1            2               0
# 320              0               1            2               0
# 321              0               1            2               0
# 322              0               1            2               0
#
#      precision_top10  recall_top10  accuracy_top20  precision_top20  \
# 0                  1             2               0                1
# 1                  1             2               0                1
# 2                  1             2               0                1
# 3                  1             2               0                1
# 4                  1             2               0                1
# ..               ...           ...             ...              ...
# 318                1             2               0                1
# 319                1             2               0                1
# 320                1             2               0                1
# 321                1             2               0                1
# 322                1             2               0                1
#
#      recall_top20
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# ..            ...
# 318             2
# 319             2
# 320             2
# 321             2
# 322             2
#
# [323 rows x 21 columns]

# %%
retrieval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   query_id               300 non-null    object
#  1   query                  300 non-null    object
#  2   retrieved_docs_top50   300 non-null    object
#  3   retrieved_texts_top50  300 non-null    object
#  4   retrieved_sim_top50    300 non-null    object
#  5   relevant_docs          300 non-null    object
#  6   accuracy_top1          300 non-null    int64
#  7   precision_inner_top1   300 non-null    int64
#  8   precision_ohe_top1     300 non-null    int64
#  9   recall_ohe_top1        300 non-null    int64
#  10  accuracy_top3          300 non-null    int64
#  11  precision_inner_top3   300 non-null    int64
#  12  precision_ohe_top3     300 non-null    int64
#  13  recall_ohe_top3        300 non-null    int64
#  14  accuracy_top5          300 non-null    int64
#  15  precision_inner_top5   300 non-null    int64
#  16  precision_ohe_top5     300 non-null    int64
#  17  recall_ohe_top5        300 non-null    int64
#  18  accuracy_top10         300 non-null    int64
#  19  precision_inner_top10  300 non-null    int64
#  20  precision_ohe_top10    300 non-null    int64
#  21  recall_ohe_top10       300 non-null    int64
#  22  accuracy_top20         300 non-null    int64
#  23  precision_inner_top20  300 non-null    int64
#  24  precision_ohe_top20    300 non-null    int64
#  25  recall_ohe_top20       300 non-null    int64
# dtypes: int64(20), object(6)
# memory usage: 61.1+ KB

# %%
def compute_metrics(retrieval_df, top_k=10, reranked=False):
    # Compute the mean accuracy, precision, and recall
    accuracy_ft = f"accuracy_top{top_k}"
    precision_inner_ft = f"precision_inner_top{top_k}"
    precision_ohe_ft = f"precision_ohe_top{top_k}"
    recall_ohe_ft = f"recall_ohe_top{top_k}"
    
    accuracy = retrieval_df[accuracy_ft].mean()
    precision_inner = retrieval_df[precision_inner_ft].mean()
    precision_ohe = retrieval_df[precision_ohe_ft].mean()
    recall_ohe = retrieval_df[recall_ohe_ft].mean()
    
    temp_df = pd.DataFrame({
        'method': [f"top{top_k}"],
        'accuracy': [accuracy],
        'precision_inner': [precision_inner],
        'precision_ohe': [precision_ohe],
        'recall_ohe': [recall_ohe]
    })
    
    return temp_df

# %%
METHODS_LIST = ["cosine", "hybrid", "cross_encoder_rerank", "keyword_rerank"]
k_list = [1, 3, 5, 10, 20]

for item in os.listdir(data_path):
    if item in METHODS_LIST:
        retrieval_df = pd.read_csv(os.path.join(data_path, item, "retrieval_results.csv"))
        metrics_df = pd.DataFrame({'method': [], 'accuracy': [], 'precision_inner': [], 'precision_ohe': [], 'recall_ohe': []})
        
        for k in k_list:
            temp_df = compute_metrics(retrieval_df, top_k=k)
            metrics_df = pd.concat([metrics_df, temp_df], axis=0)
        metrics_df.to_csv(os.path.join(data_path, item, "metrics.csv"), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_348705/907699748.py in <cell line: 4>()
#       8
#       9         for k in k_list:
# ---> 10             temp_df = compute_metrics(retrieval_df, top_k=k)
#      11             metrics_df = pd.concat([metrics_df, temp_df], axis=0)
#      12         metrics_df.to_csv(os.path.join(data_path, item, "metrics.csv"), index=False)
#
# NameError: name 'compute_metrics' is not defined

# %%
retrieval_df
# Out:
#        query_id                                              query  \
# 0       PLAIN-2   Do Cholesterol Statin Drugs Cause Breast Cancer?
# 1      PLAIN-12                Exploiting Autophagy to Live Longer
# 2      PLAIN-23  How to Reduce Exposure to Alkylphenols Through...
# 3      PLAIN-33          What’s Driving America’s Obesity Problem?
# 4      PLAIN-44              Who Should be Careful About Curcumin?
# ..          ...                                                ...
# 318  PLAIN-3432                       Healthy Chocolate Milkshakes
# 319  PLAIN-3442                          The Healthiest Vegetables
# 320  PLAIN-3452                           Bowel Movement Frequency
# 321  PLAIN-3462                      Olive Oil and Artery Function
# 322  PLAIN-3472  How Doctors Responded to Being Named a Leading...
#
#                                   retrieved_docs_top50  \
# 0    ['MED-2429', 'MED-14', 'MED-2431', 'MED-10', '...
# 1    ['MED-2514', 'MED-1437', 'MED-1432', 'MED-1436...
# 2    ['MED-4726', 'MED-999', 'MED-1004', 'MED-1961'...
# 3    ['MED-2721', 'MED-2721', 'MED-2722', 'MED-2723...
# 4    ['MED-2824', 'MED-1110', 'MED-1811', 'MED-2794...
# ..                                                 ...
# 318  ['MED-1407', 'MED-5287', 'MED-5287', 'MED-1411...
# 319  ['MED-2098', 'MED-860', 'MED-1407', 'MED-2201'...
# 320  ['MED-1048', 'MED-1042', 'MED-1034', 'MED-1040...
# 321  ['MED-1373', 'MED-5274', 'MED-5260', 'MED-1390...
# 322  ['MED-1053', 'MED-1351', 'MED-2750', 'MED-3603...
#
#                                  retrieved_texts_top50  \
# 0    ["Emerging evidence suggests that statins' may...
# 1    ["Healthy life span is rapidly increasing and ...
# 2    ["The aim of these studies was to evaluate the...
# 3    ['BACKGROUND: The major drivers of the obesity...
# 4    ['Cancer is primarily a disease of old age, an...
# ..                                                 ...
# 318  ['The Mediterranean tradition offers a cousine...
# 319  ['Steam cooking significantly improved the in ...
# 320  ['Because the range of bowel habits and stool ...
# 321  ['The endothelium is involved in many of the p...
# 322  ["CONTEXT: While some studies have shown that ...
#
#                                    retrieved_sim_top50  \
# 0    [0.9891527891159058, 0.9874821901321411, 0.986...
# 1    [0.9835842847824097, 0.9829482436180115, 0.981...
# 2    [0.9849041700363159, 0.9845057129859924, 0.983...
# 3    [0.9824672937393188, 0.9813079833984375, 0.981...
# 4    [0.979678750038147, 0.9796613454818726, 0.9795...
# ..                                                 ...
# 318  [0.9795540571212769, 0.979552149772644, 0.9787...
# 319  [0.9841075539588928, 0.9837210774421692, 0.982...
# 320  [0.9899636507034302, 0.9897537231445312, 0.988...
# 321  [0.9915293455123901, 0.9907785654067993, 0.990...
# 322  [0.9823046326637268, 0.9806137681007385, 0.980...
#
#                                          relevant_docs  accuracy_top1  \
# 0    ['MED-2427', 'MED-10', 'MED-2429', 'MED-2430',...              0
# 1    ['MED-2513', 'MED-5237', 'MED-2517', 'MED-2518...              0
# 2    ['MED-2644', 'MED-2646', 'MED-2651', 'MED-118'...              0
# 3    ['MED-2717', 'MED-2715', 'MED-2716', 'MED-2718...              0
# 4    ['MED-2780', 'MED-2810', 'MED-2787', 'MED-2788...              0
# ..                                                 ...            ...
# 318  ['MED-2274', 'MED-3535', 'MED-2222', 'MED-2223...              0
# 319  ['MED-5159', 'MED-5160', 'MED-5161', 'MED-5162...              0
# 320  ['MED-5177', 'MED-5175', 'MED-2099', 'MED-2100...              0
# 321  ['MED-5260', 'MED-5261', 'MED-5262', 'MED-5263...              0
# 322  ['MED-5343', 'MED-5344', 'MED-5345', 'MED-5346...              0
#
#      precision_inner_top1  precision_ohe_top1  recall_ohe_top1  ...  \
# 0                       1                   2                3  ...
# 1                       1                   2                3  ...
# 2                       1                   2                3  ...
# 3                       1                   2                3  ...
# 4                       1                   2                3  ...
# ..                    ...                 ...              ...  ...
# 318                     1                   2                3  ...
# 319                     1                   2                3  ...
# 320                     1                   2                3  ...
# 321                     1                   2                3  ...
# 322                     1                   2                3  ...
#
#      precision_ohe_top5  recall_ohe_top5  accuracy_top10  \
# 0                     2                3               0
# 1                     2                3               0
# 2                     2                3               0
# 3                     2                3               0
# 4                     2                3               0
# ..                  ...              ...             ...
# 318                   2                3               0
# 319                   2                3               0
# 320                   2                3               0
# 321                   2                3               0
# 322                   2                3               0
#
#      precision_inner_top10  precision_ohe_top10  recall_ohe_top10  \
# 0                        1                    2                 3
# 1                        1                    2                 3
# 2                        1                    2                 3
# 3                        1                    2                 3
# 4                        1                    2                 3
# ..                     ...                  ...               ...
# 318                      1                    2                 3
# 319                      1                    2                 3
# 320                      1                    2                 3
# 321                      1                    2                 3
# 322                      1                    2                 3
#
#      accuracy_top20  precision_inner_top20  precision_ohe_top20  \
# 0                 0                      1                    2
# 1                 0                      1                    2
# 2                 0                      1                    2
# 3                 0                      1                    2
# 4                 0                      1                    2
# ..              ...                    ...                  ...
# 318               0                      1                    2
# 319               0                      1                    2
# 320               0                      1                    2
# 321               0                      1                    2
# 322               0                      1                    2
#
#      recall_ohe_top20
# 0                   3
# 1                   3
# 2                   3
# 3                   3
# 4                   3
# ..                ...
# 318                 3
# 319                 3
# 320                 3
# 321                 3
# 322                 3
#
# [323 rows x 26 columns]
